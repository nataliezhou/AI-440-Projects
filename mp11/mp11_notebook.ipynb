# %% [markdown]
# # CS440/ECE448 Spring 2023
# # MP11: Reinforcement Learning

# %% [markdown]
# The first thing you need to do is to download this file: <a href="mp11.zip">mp11.zip</a>.  If you want, you can also download <a href="mp11_extra.zip">mp11_extra.zip</a>, the extra credit assignment.  `mp11.zip` has the following content:
#
# * `submitted.py`: Your homework. Edit, and then submit to <a href="https://www.gradescope.com/courses/486387">Gradescope</a>.
# * `mp11_notebook.ipynb`: This is a <a href="https://anaconda.org/anaconda/jupyter">Jupyter</a> notebook to help you debug.  You can completely ignore it if you want, although you might find that it gives you useful instructions.
# * `pong.py`: This is a program that plays Pong.  If called interactively, it will call the module `pong_display.py` to create a display, so that you can play.  If told to use a Q-learner, it will call your `submitted.py` to do Q-learning.
# * `grade.py`: Once your homework seems to be working, you can test it by typing `python grade.py`, which will run the tests in `tests/tests_visible.py`.
# * `tests/test_visible.py`: This file contains about half of the <a href="https://docs.python.org/3/library/unittest.html">unit tests</a> that Gradescope will run in order to grade your homework.  If you can get a perfect score on these tests, then you should also get a perfect score on the additional hidden tests that Gradescope uses.
# * `requirements.txt`: This tells you which python packages you need to have installed, in order to run `grade.py`.  You can install all of those packages by typing `pip install -r requirements.txt` or `pip3 install -r requirements.txt`.

# %% [markdown]
# This file (`mp11_notebook.ipynb`) will walk you through the whole MP, giving you instructions and debugging tips as you go.
#
# ### Table of Contents
#
# 1. <a href="#section1">Playing Pong</a>
# 1. <a href="#section2">Creating a Q-Learner Object</a>
# 1. <a href="#section3">Epsilon-First Exploration</a>
# 1. <a href="#section4">Q-Learning</a>
# 1. <a href="#section5">Saving and Loading Your Q and N Tables</a>
# 1. <a href="#section6">Exploitation</a>
# 1. <a href="#section7">Acting</a>
# 1. <a href="#section8">Training</a>
# 1. <a href="#section9">Extra Credit</a>
# 1. <a href="#grade">Grade Your Homework</a>

# %% [markdown]
# <a id='section1'></a>

# %% [markdown]
# ## Playing Pong

# %% [markdown]
# Pong was the <a href="https://en.wikipedia.org/wiki/Pong">first video game produced by Atari.</a>  It is a simple game, based on table tennis.  Here is a two-person version of the game: https://commons.wikimedia.org/wiki/File:Pong_Game_Test2.gif
#
# We will be playing a one-person version of the game:
#
# * When the ball hits the top, bottom, or left wall of the playing field, it bounces.
# * The right end of the playing field is open, except for the paddle.  If the ball hits the paddle, it bounces, and the player's score increments by one.  If the ball hits the open space, the game is over; the score resets to zero, and a new game begins.
#
# The game is pretty simple, but in order to get a better feeling for it, you may want to try playing it yourself.  Use the up arrow to move the paddle upward, and the down arrow to move the paddle downward.  See how high you can make your score:

# %%
# !python pong.py
# Out:
# Traceback (most recent call last):
#   File "pong.py", line 1, in <module>
#     import random, argparse, copy, submitted, json
#   File "/Users/natzhou/Desktop/CS 440/mp11/submitted.py", line 10, in <module>
#     import torch
# ImportError: No module named torch

# %% [markdown]
# Once you figure out how to use the arrow keys to control your paddle, we hope you will find that the game is not too hard for a human to play.  However, for a computer, it's difficult to know: where should the paddle be moved at each time step?  In order to see how difficult it is for a computer to play, let's ask the "random" player to play the game.
#
# **WARNING:** The following line will open a pygame window.  The pygame window will be hidden by this window -- in order to see it, you will need to minimize this window.  The pygame window will consume a lot of CPU time just waiting for the processor, so in order to kill it, you will need to come back to this window, click on the block below, then click the Jupyter "stop" button (the square button at the top of this window) in order to stop processing.

# %%
# !pip install -r requirements.txt
# !python3 pong.py --player random
# Out:
# Requirement already satisfied: gradescope-utils>=0.2.7 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (0.5.0)
# Requirement already satisfied: numpy>=1.15 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (1.24.3)
# Requirement already satisfied: pygame in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (2.3.0)
# Requirement already satisfied: torch in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (2.0.0)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from torch->-r requirements.txt (line 4)) (3.11.0)
# Requirement already satisfied: typing-extensions in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from torch->-r requirements.txt (line 4)) (4.5.0)
# Requirement already satisfied: sympy in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from torch->-r requirements.txt (line 4)) (1.11.1)
# Requirement already satisfied: networkx in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from torch->-r requirements.txt (line 4)) (2.6.3)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from torch->-r requirements.txt (line 4)) (3.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jinja2->torch->-r requirements.txt (line 4)) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from sympy->torch->-r requirements.txt (line 4)) (1.3.0)
# ^C
# Traceback (most recent call last):
#   File "/Users/natzhou/Desktop/CS 440/mp11/pong.py", line 266, in <module>
#     application = PongGame(ball_speed=ball_speed,
#   File "/Users/natzhou/Desktop/CS 440/mp11/pong.py", line 51, in __init__
#     import pong_display
#   File "/Users/natzhou/Desktop/CS 440/mp11/pong_display.py", line 1, in <module>
#     import pygame, sys
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pygame/__init__.py", line 246, in <module>
#     import pygame.mixer_music
#   File "<frozen importlib._bootstrap>", line 203, in _lock_unlock_module
# KeyboardInterrupt

# %%
# !pip install -r requirements.txt
# !python3 pong.py --player random

# %% [markdown]
# <a id='section2'></a>

# %% [markdown]
# ## Creating a Q-Learner Object

# %% [markdown]
# The first thing you will do is to create a `q_learner` object that can store your learned Q table and your N table (table of exploration counts).
#
# Like any other object-oriented language, python permits you to create new object classes in order to store data that will be needed from time to time.  If you are not already very, very familiar with python classes, you might want to study the python class tutorial: https://docs.python.org/3/tutorial/classes.html
#
# Like any other object in python, a `q_learner` object is created by calling its name as a function, e.g., `my_q_learner=submitted.q_learner()`.  Doing so calls the function `submitted.q_learner.__init__()`.  Let's look at the docstring to see what it should do.

# %%
import submitted, importlib
importlib.reload(submitted)
help(submitted.q_learner.__init__)
# Out:
# Help on function __init__ in module submitted:
#
# __init__(self, alpha, epsilon, gamma, nfirst, state_cardinality)
#     Create a new q_learner object.
#     Your q_learner object should store the provided values of alpha,
#     epsilon, gamma, and nfirst.
#     It should also create a Q table and an N table.
#     Q[...state..., ...action...] = expected utility of state/action pair.
#     N[...state..., ...action...] = # times state/action has been explored.
#     Both are initialized to all zeros.
#     Up to you: how will you encode the state and action in order to
#     define these two lookup tables?  The state will be a list of 5 integers,
#     such that 0 <= state[i] < state_cardinality[i] for 0 <= i < 5.
#     The action will be either -1, 0, or 1.
#     It is up to you to decide how to convert an input state and action
#     into indices that you can use to access your stored Q and N tables.
#
#     @params:
#     alpha (scalar) - learning rate of the Q-learner
#     epsilon (scalar) - probability of taking a random action
#     gamma (scalar) - discount factor
#     nfirst (scalar) - exploring each state/action pair nfirst times before exploiting
#     state_cardinality (list) - cardinality of each of the quantized state variables
#
#     @return:
#     None

# %% [markdown]
# Write your `__init__` function to meet the requirements specified in the docstring.  Once you have completed it, the following code should run without errors:

# %%
importlib.reload(submitted)

q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])

print(q_learner)
# Out:
# <submitted.q_learner object at 0x7f8a184a46a0>

# %% [markdown]
# <a id='section3'></a>

# %% [markdown]
# ## Epsilon-First Exploration

# %% [markdown]
# In order to manage the exploration/exploitation tradeoff, we will be using both "epsilon-first" and "epsilon-greedy" (https://en.wikipedia.org/wiki/Multi-armed_bandit#Semi-uniform_strategies).
#
# The epsilon-first strategy explores every state/action pair at least `nfirst` times before it ever starts to exploit any strategy.  Your `q_learner` should have a table to keep track of how many times it has explored a state/action pair prior to the start of any exploitation.  The method for storing that table is up to you; in order to have some standardized API, therefore, you need to write a method called `report_exploration_counts` that returns a list of the three exploration counts for a given state.

# %%
importlib.reload(submitted)
help(submitted.q_learner.report_exploration_counts)
# Out:
# Help on function report_exploration_counts in module submitted:
#
# report_exploration_counts(self, state)
#     Check to see how many times each action has been explored in this state.
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     explored_count (array of 3 ints):
#       number of times that each action has been explored from this state.
#       The mapping from actions to integers is up to you, but there must be three of them.

# %% [markdown]
# Write `report_exploration_counts` so that it returns a list or array for any given state.  Test your code with the following:

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('This is how many times state [0,0,0,0,0] has been explored so far:')
print(q_learner.report_exploration_counts([0,0,0,0,0]))
print('This is how many times state [9,9,1,1,9] has been explored so far:')
print(q_learner.report_exploration_counts([9,9,1,1,9]))
# Out:
# This is how many times state [0,0,0,0,0] has been explored so far:
# [0. 0. 0.]
# This is how many times state [9,9,1,1,9] has been explored so far:
# [0. 0. 0.]

# %% [markdown]
# When your learner first starts learning, it will call the function `choose_unexplored_action` to choose an unexplored action.  This function should choose a function uniformly at random from the set of unexplored actions in a given state, if there are any:

# %%
importlib.reload(submitted)
help(submitted.q_learner.choose_unexplored_action)
# Out:
# Help on function choose_unexplored_action in module submitted:
#
# choose_unexplored_action(self, state)
#     Choose an action that has been explored less than nfirst times.
#     If many actions are underexplored, you should choose uniformly
#     from among those actions; don't just choose the first one all
#     the time.
#
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#        These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     action (scalar): either -1, or 0, or 1, or None
#       If all actions have been explored at least n_explore times, return None.
#       Otherwise, choose one uniformly at random from those w/count less than n_explore.
#       When you choose an action, you should increment its count in your counter table.

# %% [markdown]
# If this has been written correctly, the following block should generate a random sequence of actions.  If the next block produces the same action 5 times in a row, that is the wrong result, and the result would be that your code does not pass the autograder.

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
# Out:
# Next action: -1
# Next action: 1
# Next action: -1
# Next action: 1
# Next action: 0

# %% [markdown]
# After all three actions have been explored `nfirst` times, the function `choose_unexplored_action` should return `None`, as shown here:

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,1,[10,10,2,2,10])
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
# Out:
# Next action: 0
# Next action: 1
# Next action: -1
# Next action: None

# %% [markdown]
# <a id='section4'></a>

# %% [markdown]
# ## Q-Learning

# %% [markdown]
# The reinforcement learning we are implementing is called Q-learning (https://en.wikipedia.org/wiki/Q-learning).
#
# Q-learning keeps a table $Q[s,a]$ that specifies the expected utility of action $a$ in state $s$.  The organization of this table is up to you.  In order to have a standard API, the first thing you should implement is a function `report_q` with the following docstring:

# %%
importlib.reload(submitted)
help(submitted.q_learner.report_q)
# Out:
# Help on function report_q in module submitted:
#
# report_q(self, state)
#     Report the current Q values for the given state.
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     Q (array of 3 floats):
#       reward plus expected future utility of each of the three actions.
#       The mapping from actions to integers is up to you, but there must be three of them.

# %% [markdown]
# When your `q_learner` is first initialized, the value of $Q[state,action]$ should be zero for all state/action pairs, thus the `report_q` function should return lists of zeros:

# %%
importlib.reload(submitted)
q_learner=submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('Q[0,0,0,0,0] is now:',q_learner.report_q([0,0,0,0,0]))
print('Q[9,9,1,1,9] is now:',q_learner.report_q([9,9,1,1,9]))
# Out:
# Q[0,0,0,0,0] is now: [0. 0. 0.]
# Q[9,9,1,1,9] is now: [0. 0. 0.]

# %% [markdown]
# There are actually many different Q-learning algorithms available, but when people refer to Q-learning with no modifier, they usually mean the time-difference (TD) algorithm.  For example, this is the algorithm that's described on the wikipedia page (https://en.wikipedia.org/wiki/Q-learning).  This is the algorithm you will implement for this MP.
#
# In supervised machine learning, the learner tries to imitate a reference label.  In reinforcement learning, there is no reference label.  Q-learning replaces the reference label with a "local Q" value, which is the utility that was obtained by performing action $a$ in state $s$ one time.  It is usually calculated like this:
#
# $$Q_{local}(s_t,a_t) = r_t + \gamma\max_{a_{t+1}}Q(s_{t+1},a_{t+1})$$
#
# where $r_t$ is the reward that was achieved by performing action $a_t$ in state $s_t$, $s_{t+1}$ is the state into which the game transitioned, and $a_{t+1}$ is one of the actions that could be performed in that state.  $Q_{local}$ is computed by your `q_local` function, which has this docstring:

# %%
importlib.reload(submitted)
help(submitted.q_learner.q_local)
# Out:
# Help on function q_local in module submitted:
#
# q_local(self, reward, newstate)
#     The update to Q estimated from a single step of game play:
#     reward plus gamma times the max of Q[newstate, ...].
#
#     @param:
#     reward (scalar float): the reward achieved from the current step of game play.
#     newstate (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     Q_local (scalar float): the local value of Q

# %% [markdown]
# Initially, `q_local` should just return the given reward, because initially, all Q values are 0:

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,10,10])
print('Q_local(6.25,[9,9,1,1,9]) is currently:',q_learner.q_local(6.25,[9,9,1,1,9]))
# Out:
# Q_local(6.25,[9,9,1,1,9]) is currently: 6.25

# %% [markdown]
# Now you can use `q_learner.q_local` as the target for `q_learner.learn`.  The basic algorithm is
#
# $$Q(s,a) = Q(s,a) + \alpha (Q_{local}(s,a)-Q(s,a))$$
#
# Here is the docstring:

# %%
importlib.reload(submitted)
help(submitted.q_learner.learn)
# Out:
# Help on function learn in module submitted:
#
# learn(self, state, action, reward, newstate)
#     Update the internal Q-table on the basis of an observed
#     state, action, reward, newstate sequence.
#
#     @params:
#     state: a list of 5 numbers: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle.
#     action: an integer, one of -1, 0, or +1
#     reward: a reward; positive for hitting the ball, negative for losing a game
#     newstate: a list of 5 numbers, in the same format as state
#
#     @return:
#     None

# %% [markdown]
# The following block checks a sequence of Q updates:
#
# 1. First, $Q([9,9,1,1,9],-1)$ is updated.  Since all Q values start at zero, it will be updated to just have a value equal to $\alpha$ (0.05) times the given reward (6.25) for a total value of 0.3125.
# 1. When we print out $Q([9,9,1,1,9],:)$, we see that one of the elements has been updated.
# 1. Next, update $Q([9,9,1,1,8],1)$ with a given reward, and with $[9,9,1,1,9]$ as the given next state.  Since $Q([9,9,1,1,9],-1)$ is larger than zero, the next-state Q-value should be multiplied by $\gamma$ (0.99) and added to the reward (3.1), then multiplied by $\alpha$, giving a total value of 0.17046875.
# 1. The resulting Q-value is reported.

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
q_learner.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('Q[9,9,1,1,9] is now',q_learner.report_q([9,9,1,1,9]))
q_learner.learn([9,9,1,1,8],1,3.1,[9,9,1,1,9])
print('Q[9,9,1,1,8] is now',q_learner.report_q([9,9,1,1,8]))
# Out:
# Q[9,9,1,1,9] is now [0.     0.     0.3125]
# Q[9,9,1,1,8] is now [0.         0.17046875 0.        ]

# %% [markdown]
# <a id='section5'></a>

# %% [markdown]
# ## Saving and Loading your Q and N Tables

# %% [markdown]
# After you've spent a long time training your `q_learner`, you will want to save your Q and N tables so that you can reload them later.  The format of Q and N is up to you, therefore it's also up to you to write the `save` and `load` functions.  Here are the docstrings:

# %%
importlib.reload(submitted)
help(submitted.q_learner.save)
# Out:
# Help on function save in module submitted:
#
# save(self, filename)
#     Save your Q and N tables to a file.
#     This can save in any format you like, as long as your "load"
#     function uses the same file format.  We recommend numpy.savez,
#     but you can use something else if you prefer.
#
#     @params:
#     filename (str) - filename to which it should be saved
#     @return:
#     None

# %%
importlib.reload(submitted)
help(submitted.q_learner.load)
# Out:
# Help on function load in module submitted:
#
# load(self, filename)
#     Load the Q and N tables from a file.
#     This should load from whatever file format your save function
#     used.  We recommend numpy.load, but you can use something
#     else if you prefer.
#
#     @params:
#     filename (str) - filename from which it should be loaded
#     @return:
#     None

# %% [markdown]
# These functions can be tested by doing one step of training one `q_learner`, then saving its results, then loading them into another `q_learner`:

# %%
importlib.reload(submitted)
q_learner1 = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('Next action:',q_learner1.choose_unexplored_action([9,9,1,1,9]))
q_learner1.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('N1[9,9,1,1,8] is now',q_learner1.report_exploration_counts([9,9,1,1,9]))
print('Q1[9,9,1,1,8] is now',q_learner1.report_q([9,9,1,1,9]))
q_learner1.save('test.npz')

q_learner2 = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('N2[9,9,1,1,8] starts out as',q_learner2.report_exploration_counts([9,9,1,1,9]))
print('Q2[9,9,1,1,8] starts out as',q_learner2.report_q([9,9,1,1,9]))
q_learner2.load('test.npz')
print('N2[9,9,1,1,8] is now',q_learner2.report_exploration_counts([9,9,1,1,9]))
print('Q2[9,9,1,1,8] is now',q_learner2.report_q([9,9,1,1,9]))
# Out:
# Next action: -1
# N1[9,9,1,1,8] is now [0. 0. 1.]
# Q1[9,9,1,1,8] is now [0.     0.     0.3125]
# N2[9,9,1,1,8] starts out as [0. 0. 0.]
# Q2[9,9,1,1,8] starts out as [0. 0. 0.]
# N2[9,9,1,1,8] is now [0. 0. 1.]
# Q2[9,9,1,1,8] is now [0.     0.     0.3125]

# %% [markdown]
# <a id='section6'></a>

# %% [markdown]
# ## Exploitation

# %% [markdown]
# A reinforcement learner always has to trade off between exploration (choosing an action at random) versus exploitation (choosing the action with the maximum expected utility).  Before we worry about that tradeoff, though, let's first make sure that exploitation works.

# %%
importlib.reload(submitted)
help(submitted.q_learner.exploit)
# Out:
# Help on function exploit in module submitted:
#
# exploit(self, state)
#     Return the action that has the highest Q-value for the current state, and its Q-value.
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     action (scalar int): either -1, or 0, or 1.
#       The action that has the highest Q-value.  Ties can be broken any way you want.
#     Q (scalar float):
#       The Q-value of the selected action

# %%
importlib.reload(submitted)
q_learner1 = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
q_learner1.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('Q1[9,9,1,1,9] is now',q_learner1.report_q([9,9,1,1,9]))
print('The best action and Q from state [9,9,1,1,9] are',q_learner1.exploit([9,9,1,1,9]))
# Out:
# Q1[9,9,1,1,9] is now [0.     0.     0.3125]
# The best action and Q from state [9,9,1,1,9] are (1, 0.3125)

# %% [markdown]
# <a id='section7'></a>

# %% [markdown]
# ## Acting

# %% [markdown]
# When your learner decides which action to perform, it should trade off exploration vs. exploitation using both the epsilon-first and the epsilon-greedy strategies:
# 1. If there is any action that has been explored fewer than `nfirst` times, then choose one of those actions at random.  Otherwise...
# 1. With probability `epsilon`, choose an action at random.  Otherwise...
# 1. Exploit.

# %%
importlib.reload(submitted)
help(submitted.q_learner.act)
# Out:
# Help on function act in module submitted:
#
# act(self, state)
#     Decide what action to take in the current state.
#     If any action has been taken less than nfirst times, then choose one of those
#     actions, uniformly at random.
#     Otherwise, with probability epsilon, choose an action uniformly at random.
#     Otherwise, choose the action with the best Q(state,action).
#
#     @params:
#     state: a list of 5 integers: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     -1 if the paddle should move upward
#     0 if the paddle should be stationary
#     1 if the paddle should move downward

# %% [markdown]
# In order to test all three types of action (epsilon-first exploration, epsilon-greedy exploration, and exploitation), let's create a learner with `nfirst=1` and `epsilon=0.25`, and set it so that the best action from state `[9,9,1,1,9]` is `-1`.  With these settings, a sequence of calls to `q_learner.act` should produce the following sequence of actions:
#
# 1. The first three actions should include each possible action once.
# 1. After the first three actions, 3/4 of the remaining actions should be `-1`.  The remaining 1/4 should be randomly chosen.

# %%
importlib.reload(submitted)
q_learner=submitted.q_learner(0.05,0.25,0.99,1,[10,10,2,2,10])
q_learner.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('An epsilon-first action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-first action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-first action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
# Out:
# An epsilon-first action: 0
# An epsilon-first action: 1
# An epsilon-first action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: 1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1

# %% [markdown]
# <a id='section8'></a>

# %% [markdown]
# ## Training

# %% [markdown]
# Now that all of your components work, you can try training your algorithm.  Do this by giving your `q_learner` as a player to a new `pong.PongGame` object.  Set `visibility=False` so that the `PongGame` doesn't create a new window.

# %%
import pong, importlib, submitted
importlib.reload(pong)
help(pong.PongGame.__init__)
# Out:
# Help on function __init__ in module pong:
#
# __init__(self, ball_speed=4, paddle_speed=8, learner=None, visible=True, state_quantization=[10, 10, 2, 2, 10])
#     Create a new pong game, with a specified player.
#
#     @params:
#     ball_speed (scalar int) - average ball speed in pixels/frame
#     paddle_speed (scalar int) - paddle moves 0, +paddle_speed, or -paddle_speed
#     learner - can be None if the player is human.  If not None, should be an
#       object of type random_learner, submitted.q_learner, or submitted.deep_q.
#     visible (bool) - should this game have an attached pygame window?
#     state_quantization (list) - if not None, state variables are quantized
#       into integers of these cardinalities before being passed to the learner.

# %% [markdown]
# As you can see, we should set `visibility=False` so that the `PongGame` doesn't create a new window.  We should also make sure that the PongGame uses the same state quantization as the learner.

# %%
importlib.reload(pong)
importlib.reload(submitted)
state_quantization = [10,10,2,2,10]
q_learner=submitted.q_learner(0.05,0.05,0.99,5,state_quantization)

pong_game = pong.PongGame(learner=q_learner, visible=False, state_quantization=state_quantization)
print(pong_game)
# Out:
# <pong.PongGame object at 0x7f8a2166f820>

# %% [markdown]
# In order to train our learner, we want it to play the game many times.  To do that we use the PongGame.run function:

# %%
help(pong_game.run)
# Out:
# Help on method run in module pong:
#
# run(m_rewards=inf, m_games=inf, m_frames=inf, states=[]) method of pong.PongGame instance
#     Run the game.
#     @param
#     m_frames (scalar int): maximum number of frames to be played
#     m_rewards (scalar int): maximum number of rewards earned (+ or -)
#     m_games (scalar int): maximum number of games
#     states (list): list of states whose Q-values should be returned
#        each state is a list of 5 ints: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#        These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#        and the y-position of the paddle, all quantized.
#        0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#
#     @return
#     scores (list): list of scores of all completed games
#
#     The following will be returned only if the player is q_learning or deep_q.
#     New elements will be added to these lists once/frame if m_frames is specified,
#     else once/reward if m_rewards is specified, else once/game:
#       q_achieved (list): list of the q-values of the moves that were taken
#       q_states (list): list of the q-values of requested states

# %% [markdown]
# In order to make sure our learner is learning, let's tell `pong_game.run` to output all 3 Q-values of all of the 4000 states in every time step.
#
# To make sure that's not an outrageous amount of data, let's tell it to only output the Q values once/reward, and ask it to only collect 5000 rewards:

# %%
states = [[x,y,vx,vy,py] for x in range(10) for y in range(10) for vx in range(2) for vy in range(2) for py in range(10) ]

scores, q_achieved, q_states = pong_game.run(m_rewards=500, states=states)

print('The number of games played was',len(scores))
print('The number of rewards was',len(q_states))
print('The size of each returned Q-matrix was',q_states[0].shape)
# Out:
# Completed 0 games, 1 rewards, 209 frames, score 0, max score 0
# Completed 1 games, 2 rewards, 390 frames, score 0, max score 0
# Completed 2 games, 3 rewards, 644 frames, score 0, max score 0
# Completed 3 games, 4 rewards, 852 frames, score 0, max score 0
# Completed 4 games, 5 rewards, 1033 frames, score 0, max score 0
# Completed 5 games, 7 rewards, 1461 frames, score 1, max score 1
# Completed 6 games, 8 rewards, 1642 frames, score 0, max score 1
# Completed 7 games, 10 rewards, 2009 frames, score 1, max score 1
# Completed 8 games, 11 rewards, 2217 frames, score 0, max score 1
# Completed 9 games, 12 rewards, 2425 frames, score 0, max score 1
# Completed 10 games, 13 rewards, 2606 frames, score 0, max score 1
# Completed 11 games, 17 rewards, 3910 frames, score 3, max score 3
# Completed 12 games, 19 rewards, 4321 frames, score 1, max score 3
# Completed 13 games, 20 rewards, 4502 frames, score 0, max score 3
# Completed 14 games, 22 rewards, 5164 frames, score 1, max score 3
# Completed 15 games, 23 rewards, 5345 frames, score 0, max score 3
# Completed 16 games, 24 rewards, 5599 frames, score 0, max score 3
# Completed 17 games, 25 rewards, 5780 frames, score 0, max score 3
# Completed 18 games, 26 rewards, 5988 frames, score 0, max score 3
# Completed 19 games, 27 rewards, 6242 frames, score 0, max score 3
# Completed 20 games, 28 rewards, 6450 frames, score 0, max score 3
# Completed 21 games, 29 rewards, 6658 frames, score 0, max score 3
# Completed 22 games, 30 rewards, 6839 frames, score 0, max score 3
# Completed 23 games, 31 rewards, 7047 frames, score 0, max score 3
# Completed 24 games, 33 rewards, 7475 frames, score 1, max score 3
# Completed 25 games, 34 rewards, 7729 frames, score 0, max score 3
# Completed 26 games, 37 rewards, 8529 frames, score 2, max score 3
# Completed 27 games, 38 rewards, 8783 frames, score 0, max score 3
# Completed 28 games, 39 rewards, 8964 frames, score 0, max score 3
# Completed 29 games, 40 rewards, 9172 frames, score 0, max score 3
# Completed 30 games, 41 rewards, 9426 frames, score 0, max score 3
# Completed 31 games, 42 rewards, 9607 frames, score 0, max score 3
# Completed 32 games, 45 rewards, 10364 frames, score 2, max score 3
# Completed 33 games, 48 rewards, 10972 frames, score 2, max score 3
# Completed 34 games, 49 rewards, 11180 frames, score 0, max score 3
# Completed 35 games, 50 rewards, 11361 frames, score 0, max score 3
# Completed 36 games, 52 rewards, 11821 frames, score 1, max score 3
# Completed 37 games, 55 rewards, 12570 frames, score 2, max score 3
# Completed 38 games, 57 rewards, 12937 frames, score 1, max score 3
# Completed 39 games, 60 rewards, 13749 frames, score 2, max score 3
# Completed 40 games, 61 rewards, 13930 frames, score 0, max score 3
# Completed 41 games, 62 rewards, 14111 frames, score 0, max score 3
# Completed 42 games, 63 rewards, 14292 frames, score 0, max score 3
# Completed 43 games, 64 rewards, 14546 frames, score 0, max score 3
# Completed 44 games, 65 rewards, 14754 frames, score 0, max score 3
# Completed 45 games, 66 rewards, 14935 frames, score 0, max score 3
# Completed 46 games, 67 rewards, 15189 frames, score 0, max score 3
# Completed 47 games, 68 rewards, 15370 frames, score 0, max score 3
# Completed 48 games, 69 rewards, 15551 frames, score 0, max score 3
# Completed 49 games, 71 rewards, 16141 frames, score 1, max score 3
# Completed 50 games, 72 rewards, 16349 frames, score 0, max score 3
# Completed 51 games, 73 rewards, 16557 frames, score 0, max score 3
# Completed 52 games, 74 rewards, 16738 frames, score 0, max score 3
# Completed 53 games, 75 rewards, 16946 frames, score 0, max score 3
# Completed 54 games, 78 rewards, 18694 frames, score 2, max score 3
# Completed 55 games, 79 rewards, 18902 frames, score 0, max score 3
# Completed 56 games, 80 rewards, 19110 frames, score 0, max score 3
# Completed 57 games, 81 rewards, 19318 frames, score 0, max score 3
# Completed 58 games, 83 rewards, 20052 frames, score 1, max score 3
# Completed 59 games, 84 rewards, 20233 frames, score 0, max score 3
# Completed 60 games, 86 rewards, 20895 frames, score 1, max score 3
# Completed 61 games, 87 rewards, 21103 frames, score 0, max score 3
# Completed 62 games, 89 rewards, 21499 frames, score 1, max score 3
# Completed 63 games, 91 rewards, 21962 frames, score 1, max score 3
# Completed 64 games, 92 rewards, 22143 frames, score 0, max score 3
# Completed 65 games, 93 rewards, 22397 frames, score 0, max score 3
# Completed 66 games, 94 rewards, 22578 frames, score 0, max score 3
# Completed 67 games, 95 rewards, 22786 frames, score 0, max score 3
# Completed 68 games, 96 rewards, 22994 frames, score 0, max score 3
# Completed 69 games, 97 rewards, 23202 frames, score 0, max score 3
# Completed 70 games, 98 rewards, 23410 frames, score 0, max score 3
# Completed 71 games, 101 rewards, 24294 frames, score 2, max score 3
# Completed 72 games, 102 rewards, 24548 frames, score 0, max score 3
# Completed 73 games, 104 rewards, 24959 frames, score 1, max score 3
# Completed 74 games, 105 rewards, 25167 frames, score 0, max score 3
# Completed 75 games, 106 rewards, 25348 frames, score 0, max score 3
# Completed 76 games, 107 rewards, 25556 frames, score 0, max score 3
# Completed 77 games, 108 rewards, 25737 frames, score 0, max score 3
# Completed 78 games, 109 rewards, 25945 frames, score 0, max score 3
# Completed 79 games, 113 rewards, 26714 frames, score 3, max score 3
# Completed 80 games, 115 rewards, 27248 frames, score 1, max score 3
# Completed 81 games, 116 rewards, 27456 frames, score 0, max score 3
# Completed 82 games, 118 rewards, 27839 frames, score 1, max score 3
# Completed 83 games, 119 rewards, 28020 frames, score 0, max score 3
# Completed 84 games, 120 rewards, 28274 frames, score 0, max score 3
# Completed 85 games, 121 rewards, 28455 frames, score 0, max score 3
# Completed 86 games, 122 rewards, 28663 frames, score 0, max score 3
# Completed 87 games, 124 rewards, 29197 frames, score 1, max score 3
# Completed 88 games, 126 rewards, 29859 frames, score 1, max score 3
# Completed 89 games, 127 rewards, 30040 frames, score 0, max score 3
# Completed 90 games, 128 rewards, 30294 frames, score 0, max score 3
# Completed 91 games, 129 rewards, 30475 frames, score 0, max score 3
# Completed 92 games, 130 rewards, 30683 frames, score 0, max score 3
# Completed 93 games, 131 rewards, 30891 frames, score 0, max score 3
# Completed 94 games, 132 rewards, 31145 frames, score 0, max score 3
# Completed 95 games, 134 rewards, 31608 frames, score 1, max score 3
# Completed 96 games, 140 rewards, 33994 frames, score 5, max score 5
# Completed 97 games, 143 rewards, 34924 frames, score 2, max score 5
# Completed 98 games, 144 rewards, 35132 frames, score 0, max score 5
# Completed 99 games, 145 rewards, 35340 frames, score 0, max score 5
# Completed 100 games, 146 rewards, 35548 frames, score 0, max score 5
# Completed 101 games, 147 rewards, 35802 frames, score 0, max score 5
# Completed 102 games, 151 rewards, 36861 frames, score 3, max score 5
# Completed 103 games, 152 rewards, 37069 frames, score 0, max score 5
# Completed 104 games, 153 rewards, 37250 frames, score 0, max score 5
# Completed 105 games, 154 rewards, 37431 frames, score 0, max score 5
# Completed 106 games, 155 rewards, 37685 frames, score 0, max score 5
# Completed 107 games, 157 rewards, 38052 frames, score 1, max score 5
# Completed 108 games, 158 rewards, 38306 frames, score 0, max score 5
# Completed 109 games, 159 rewards, 38514 frames, score 0, max score 5
# Completed 110 games, 160 rewards, 38695 frames, score 0, max score 5
# Completed 111 games, 164 rewards, 40436 frames, score 3, max score 5
# Completed 112 games, 165 rewards, 40690 frames, score 0, max score 5
# Completed 113 games, 166 rewards, 40871 frames, score 0, max score 5
# Completed 114 games, 167 rewards, 41079 frames, score 0, max score 5
# Completed 115 games, 170 rewards, 41661 frames, score 2, max score 5
# Completed 116 games, 171 rewards, 41869 frames, score 0, max score 5
# Completed 117 games, 172 rewards, 42077 frames, score 0, max score 5
# Completed 118 games, 173 rewards, 42258 frames, score 0, max score 5
# Completed 119 games, 174 rewards, 42512 frames, score 0, max score 5
# Completed 120 games, 175 rewards, 42766 frames, score 0, max score 5
# Completed 121 games, 176 rewards, 42974 frames, score 0, max score 5
# Completed 122 games, 178 rewards, 43564 frames, score 1, max score 5
# Completed 123 games, 179 rewards, 43772 frames, score 0, max score 5
# Completed 124 games, 183 rewards, 44621 frames, score 3, max score 5
# Completed 125 games, 184 rewards, 44829 frames, score 0, max score 5
# Completed 126 games, 189 rewards, 45578 frames, score 4, max score 5
# Completed 127 games, 191 rewards, 46497 frames, score 1, max score 5
# Completed 128 games, 192 rewards, 46751 frames, score 0, max score 5
# Completed 129 games, 196 rewards, 47864 frames, score 3, max score 5
# Completed 130 games, 197 rewards, 48072 frames, score 0, max score 5
# Completed 131 games, 198 rewards, 48253 frames, score 0, max score 5
# Completed 132 games, 200 rewards, 48732 frames, score 1, max score 5
# Completed 133 games, 201 rewards, 48913 frames, score 0, max score 5
# Completed 134 games, 203 rewards, 49254 frames, score 1, max score 5
# Completed 135 games, 205 rewards, 49682 frames, score 1, max score 5
# Completed 136 games, 207 rewards, 49864 frames, score 1, max score 5
# Completed 137 games, 208 rewards, 50072 frames, score 0, max score 5
# Completed 138 games, 209 rewards, 50326 frames, score 0, max score 5
# Completed 139 games, 211 rewards, 50754 frames, score 1, max score 5
# Completed 140 games, 212 rewards, 50962 frames, score 0, max score 5
# Completed 141 games, 213 rewards, 51216 frames, score 0, max score 5
# Completed 142 games, 215 rewards, 51568 frames, score 1, max score 5
# Completed 143 games, 216 rewards, 51749 frames, score 0, max score 5
# Completed 144 games, 217 rewards, 51930 frames, score 0, max score 5
# Completed 145 games, 218 rewards, 52138 frames, score 0, max score 5
# Completed 146 games, 220 rewards, 52566 frames, score 1, max score 5
# Completed 147 games, 229 rewards, 54684 frames, score 8, max score 8
# Completed 148 games, 230 rewards, 54892 frames, score 0, max score 8
# Completed 149 games, 231 rewards, 55073 frames, score 0, max score 8
# Completed 150 games, 233 rewards, 55616 frames, score 1, max score 8
# Completed 151 games, 237 rewards, 56406 frames, score 3, max score 8
# Completed 152 games, 240 rewards, 57981 frames, score 2, max score 8
# Completed 153 games, 241 rewards, 58189 frames, score 0, max score 8
# Completed 154 games, 242 rewards, 58370 frames, score 0, max score 8
# Completed 155 games, 243 rewards, 58624 frames, score 0, max score 8
# Completed 156 games, 244 rewards, 58805 frames, score 0, max score 8
# Completed 157 games, 245 rewards, 59059 frames, score 0, max score 8
# Completed 158 games, 246 rewards, 59313 frames, score 0, max score 8
# Completed 159 games, 247 rewards, 59521 frames, score 0, max score 8
# Completed 160 games, 248 rewards, 59775 frames, score 0, max score 8
# Completed 161 games, 249 rewards, 59983 frames, score 0, max score 8
# Completed 162 games, 250 rewards, 60237 frames, score 0, max score 8
# Completed 163 games, 251 rewards, 60445 frames, score 0, max score 8
# Completed 164 games, 252 rewards, 60653 frames, score 0, max score 8
# Completed 165 games, 253 rewards, 60907 frames, score 0, max score 8
# Completed 166 games, 254 rewards, 61161 frames, score 0, max score 8
# Completed 167 games, 255 rewards, 61369 frames, score 0, max score 8
# Completed 168 games, 256 rewards, 61577 frames, score 0, max score 8
# Completed 169 games, 257 rewards, 61785 frames, score 0, max score 8
# Completed 170 games, 258 rewards, 61966 frames, score 0, max score 8
# Completed 171 games, 259 rewards, 62174 frames, score 0, max score 8
# Completed 172 games, 261 rewards, 62588 frames, score 1, max score 8
# Completed 173 games, 262 rewards, 62842 frames, score 0, max score 8
# Completed 174 games, 263 rewards, 63023 frames, score 0, max score 8
# Completed 175 games, 264 rewards, 63231 frames, score 0, max score 8
# Completed 176 games, 265 rewards, 63485 frames, score 0, max score 8
# Completed 177 games, 268 rewards, 64423 frames, score 2, max score 8
# Completed 178 games, 269 rewards, 64604 frames, score 0, max score 8
# Completed 179 games, 274 rewards, 66616 frames, score 4, max score 8
# Completed 180 games, 275 rewards, 66824 frames, score 0, max score 8
# Completed 181 games, 277 rewards, 67486 frames, score 1, max score 8
# Completed 182 games, 278 rewards, 67694 frames, score 0, max score 8
# Completed 183 games, 280 rewards, 68206 frames, score 1, max score 8
# Completed 184 games, 284 rewards, 69106 frames, score 3, max score 8
# Completed 185 games, 287 rewards, 70144 frames, score 2, max score 8
# Completed 186 games, 291 rewards, 71664 frames, score 3, max score 8
# Completed 187 games, 294 rewards, 72163 frames, score 2, max score 8
# Completed 188 games, 297 rewards, 72824 frames, score 2, max score 8
# Completed 189 games, 298 rewards, 73078 frames, score 0, max score 8
# Completed 190 games, 304 rewards, 74513 frames, score 5, max score 8
# Completed 191 games, 306 rewards, 74896 frames, score 1, max score 8
# Completed 192 games, 307 rewards, 75150 frames, score 0, max score 8
# Completed 193 games, 308 rewards, 75358 frames, score 0, max score 8
# Completed 194 games, 309 rewards, 75612 frames, score 0, max score 8
# Completed 195 games, 312 rewards, 76580 frames, score 2, max score 8
# Completed 196 games, 315 rewards, 77065 frames, score 2, max score 8
# Completed 197 games, 317 rewards, 77481 frames, score 1, max score 8
# Completed 198 games, 318 rewards, 77735 frames, score 0, max score 8
# Completed 199 games, 322 rewards, 78755 frames, score 3, max score 8
# Completed 200 games, 324 rewards, 79314 frames, score 1, max score 8
# Completed 201 games, 328 rewards, 79934 frames, score 3, max score 8
# Completed 202 games, 329 rewards, 80188 frames, score 0, max score 8
# Completed 203 games, 330 rewards, 80369 frames, score 0, max score 8
# Completed 204 games, 331 rewards, 80577 frames, score 0, max score 8
# Completed 205 games, 332 rewards, 80758 frames, score 0, max score 8
# Completed 206 games, 333 rewards, 80966 frames, score 0, max score 8
# Completed 207 games, 334 rewards, 81147 frames, score 0, max score 8
# Completed 208 games, 335 rewards, 81328 frames, score 0, max score 8
# Completed 209 games, 337 rewards, 81756 frames, score 1, max score 8
# Completed 210 games, 338 rewards, 81937 frames, score 0, max score 8
# Completed 211 games, 341 rewards, 84308 frames, score 2, max score 8
# Completed 212 games, 342 rewards, 84516 frames, score 0, max score 8
# Completed 213 games, 343 rewards, 84724 frames, score 0, max score 8
# Completed 214 games, 345 rewards, 85212 frames, score 1, max score 8
# Completed 215 games, 347 rewards, 85580 frames, score 1, max score 8
# Completed 216 games, 350 rewards, 86186 frames, score 2, max score 8
# Completed 217 games, 351 rewards, 86394 frames, score 0, max score 8
# Completed 218 games, 352 rewards, 86602 frames, score 0, max score 8
# Completed 219 games, 353 rewards, 86856 frames, score 0, max score 8
# Completed 220 games, 354 rewards, 87037 frames, score 0, max score 8
# Completed 221 games, 356 rewards, 87497 frames, score 1, max score 8
# Completed 222 games, 357 rewards, 87751 frames, score 0, max score 8
# Completed 223 games, 358 rewards, 87932 frames, score 0, max score 8
# Completed 224 games, 359 rewards, 88113 frames, score 0, max score 8
# Completed 225 games, 361 rewards, 88496 frames, score 1, max score 8
# Completed 226 games, 362 rewards, 88704 frames, score 0, max score 8
# Completed 227 games, 363 rewards, 88912 frames, score 0, max score 8
# Completed 228 games, 364 rewards, 89093 frames, score 0, max score 8
# Completed 229 games, 366 rewards, 89530 frames, score 1, max score 8
# Completed 230 games, 367 rewards, 89711 frames, score 0, max score 8
# Completed 231 games, 368 rewards, 89965 frames, score 0, max score 8
# Completed 232 games, 369 rewards, 90173 frames, score 0, max score 8
# Completed 233 games, 371 rewards, 90763 frames, score 1, max score 8
# Completed 234 games, 372 rewards, 91017 frames, score 0, max score 8
# Completed 235 games, 374 rewards, 91415 frames, score 1, max score 8
# Completed 236 games, 375 rewards, 91623 frames, score 0, max score 8
# Completed 237 games, 376 rewards, 91831 frames, score 0, max score 8
# Completed 238 games, 377 rewards, 92012 frames, score 0, max score 8
# Completed 239 games, 378 rewards, 92193 frames, score 0, max score 8
# Completed 240 games, 379 rewards, 92401 frames, score 0, max score 8
# Completed 241 games, 381 rewards, 92944 frames, score 1, max score 8
# Completed 242 games, 382 rewards, 93152 frames, score 0, max score 8
# Completed 243 games, 384 rewards, 93612 frames, score 1, max score 8
# Completed 244 games, 385 rewards, 93820 frames, score 0, max score 8
# Completed 245 games, 386 rewards, 94074 frames, score 0, max score 8
# Completed 246 games, 387 rewards, 94328 frames, score 0, max score 8
# Completed 247 games, 388 rewards, 94536 frames, score 0, max score 8
# Completed 248 games, 389 rewards, 94790 frames, score 0, max score 8
# Completed 249 games, 391 rewards, 95227 frames, score 1, max score 8
# Completed 250 games, 392 rewards, 95408 frames, score 0, max score 8
# Completed 251 games, 393 rewards, 95616 frames, score 0, max score 8
# Completed 252 games, 395 rewards, 96535 frames, score 1, max score 8
# Completed 253 games, 396 rewards, 96743 frames, score 0, max score 8
# Completed 254 games, 397 rewards, 96951 frames, score 0, max score 8
# Completed 255 games, 399 rewards, 97290 frames, score 1, max score 8
# Completed 256 games, 400 rewards, 97471 frames, score 0, max score 8
# Completed 257 games, 402 rewards, 98022 frames, score 1, max score 8
# Completed 258 games, 403 rewards, 98230 frames, score 0, max score 8
# Completed 259 games, 404 rewards, 98484 frames, score 0, max score 8
# Completed 260 games, 405 rewards, 98738 frames, score 0, max score 8
# Completed 261 games, 408 rewards, 100385 frames, score 2, max score 8
# Completed 262 games, 411 rewards, 101153 frames, score 2, max score 8
# Completed 263 games, 413 rewards, 101624 frames, score 1, max score 8
# Completed 264 games, 414 rewards, 101805 frames, score 0, max score 8
# Completed 265 games, 415 rewards, 102013 frames, score 0, max score 8
# Completed 266 games, 417 rewards, 102548 frames, score 1, max score 8
# Completed 267 games, 418 rewards, 102802 frames, score 0, max score 8
# Completed 268 games, 419 rewards, 103010 frames, score 0, max score 8
# Completed 269 games, 420 rewards, 103218 frames, score 0, max score 8
# Completed 270 games, 421 rewards, 103399 frames, score 0, max score 8
# Completed 271 games, 422 rewards, 103607 frames, score 0, max score 8
# Completed 272 games, 423 rewards, 103815 frames, score 0, max score 8
# Completed 273 games, 424 rewards, 104069 frames, score 0, max score 8
# Completed 274 games, 425 rewards, 104277 frames, score 0, max score 8
# Completed 275 games, 426 rewards, 104531 frames, score 0, max score 8
# Completed 276 games, 427 rewards, 104739 frames, score 0, max score 8
# Completed 277 games, 429 rewards, 105100 frames, score 1, max score 8
# Completed 278 games, 430 rewards, 105281 frames, score 0, max score 8
# Completed 279 games, 431 rewards, 105462 frames, score 0, max score 8
# Completed 280 games, 432 rewards, 105643 frames, score 0, max score 8
# Completed 281 games, 434 rewards, 106041 frames, score 1, max score 8
# Completed 282 games, 440 rewards, 108679 frames, score 5, max score 8
# Completed 283 games, 441 rewards, 108933 frames, score 0, max score 8
# Completed 284 games, 443 rewards, 109301 frames, score 1, max score 8
# Completed 285 games, 447 rewards, 110608 frames, score 3, max score 8
# Completed 286 games, 448 rewards, 110862 frames, score 0, max score 8
# Completed 287 games, 451 rewards, 111491 frames, score 2, max score 8
# Completed 288 games, 452 rewards, 111672 frames, score 0, max score 8
# Completed 289 games, 453 rewards, 111926 frames, score 0, max score 8
# Completed 290 games, 454 rewards, 112107 frames, score 0, max score 8
# Completed 291 games, 456 rewards, 112604 frames, score 1, max score 8
# Completed 292 games, 457 rewards, 112785 frames, score 0, max score 8
# Completed 293 games, 458 rewards, 113039 frames, score 0, max score 8
# Completed 294 games, 459 rewards, 113247 frames, score 0, max score 8
# Completed 295 games, 460 rewards, 113455 frames, score 0, max score 8
# Completed 296 games, 461 rewards, 113709 frames, score 0, max score 8
# Completed 297 games, 464 rewards, 114208 frames, score 2, max score 8
# Completed 298 games, 465 rewards, 114462 frames, score 0, max score 8
# Completed 299 games, 468 rewards, 114969 frames, score 2, max score 8
# Completed 300 games, 469 rewards, 115177 frames, score 0, max score 8
# Completed 301 games, 470 rewards, 115358 frames, score 0, max score 8
# Completed 302 games, 471 rewards, 115612 frames, score 0, max score 8
# Completed 303 games, 472 rewards, 115866 frames, score 0, max score 8
# Completed 304 games, 473 rewards, 116120 frames, score 0, max score 8
# Completed 305 games, 474 rewards, 116301 frames, score 0, max score 8
# Completed 306 games, 475 rewards, 116482 frames, score 0, max score 8
# Completed 307 games, 476 rewards, 116690 frames, score 0, max score 8
# Completed 308 games, 478 rewards, 117150 frames, score 1, max score 8
# Completed 309 games, 479 rewards, 117358 frames, score 0, max score 8
# Completed 310 games, 480 rewards, 117566 frames, score 0, max score 8
# Completed 311 games, 481 rewards, 117747 frames, score 0, max score 8
# Completed 312 games, 482 rewards, 117928 frames, score 0, max score 8
# Completed 313 games, 485 rewards, 119044 frames, score 2, max score 8
# Completed 314 games, 486 rewards, 119252 frames, score 0, max score 8
# Completed 315 games, 487 rewards, 119460 frames, score 0, max score 8
# Completed 316 games, 490 rewards, 120141 frames, score 2, max score 8
# Completed 317 games, 491 rewards, 120349 frames, score 0, max score 8
# Completed 318 games, 494 rewards, 121092 frames, score 2, max score 8
# Completed 319 games, 496 rewards, 121626 frames, score 1, max score 8
# Completed 320 games, 497 rewards, 121880 frames, score 0, max score 8
# Completed 321 games, 499 rewards, 122263 frames, score 1, max score 8
# Completed 322 games, 500 rewards, 122471 frames, score 0, max score 8
# The number of games played was 324
# The number of rewards was 500
# The size of each returned Q-matrix was (4000, 3)

# %% [markdown]
# The returned value of `q_states` is a list of 4000x3 numpy arrays (20 states, 3 actions).  The list contains `m_rewards` of these. We want to convert it into something that matplotlib can plot.

# %%
import numpy as np

Q = np.array([np.reshape(q,-1) for q in q_states])
print('Q is now of shape',Q.shape)
print('the max absolute value of Q is ',np.amax(abs(Q)))
# Out:
# Q is now of shape (500, 12000)
# the max absolute value of Q is  1.426024375

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

fig = plt.figure(figsize=(14,6),layout='tight')
ax = [ fig.add_subplot(2,1,x) for x in range(1,3) ]
ax[0].plot(np.arange(0,len(q_states)),Q)
ax[0].set_title('Q values of all states')
ax[1].plot(np.arange(0,len(q_states)),q_achieved)
ax[1].set_title('Q values of state achieved at each time')
ax[1].set_ylabel('Reward number')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/2r/cp80ny451xv3lxv7_ktzrlsw0000gp/T/ipykernel_739/1292137741.py in <module>
#       3 import matplotlib.pyplot as plt
#       4
# ----> 5 fig = plt.figure(figsize=(14,6),layout='tight')
#       6 ax = [ fig.add_subplot(2,1,x) for x in range(1,3) ]
#       7 ax[0].plot(np.arange(0,len(q_states)),Q)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     795                 RuntimeWarning)
#     796
# --> 797         manager = new_figure_manager(
#     798             num, figsize=figsize, dpi=dpi,
#     799             facecolor=facecolor, edgecolor=edgecolor, frameon=frameon,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/pyplot.py in new_figure_manager(*args, **kwargs)
#     314     """Create a new figure manager instance."""
#     315     _warn_if_gui_out_of_main_thread()
# --> 316     return _backend_mod.new_figure_manager(*args, **kwargs)
#     317
#     318
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backend_bases.py in new_figure_manager(cls, num, *args, **kwargs)
#    3542         from matplotlib.figure import Figure
#    3543         fig_cls = kwargs.pop('FigureClass', Figure)
# -> 3544         fig = fig_cls(*args, **kwargs)
#    3545         return cls.new_figure_manager_given_figure(num, fig)
#    3546
#
# TypeError: __init__() got an unexpected keyword argument 'layout'

# %% [markdown]
# OK, now let's try running it for a much longer period -- say, 5000 complete games.  We won't ask it to print out any states this time.

# %%
scores, q_achieved, q_states = pong_game.run(m_games=5000, states=[])

print('The number of games played was',len(scores))
print('The number of video frames was',len(q_states))
print('The size of each returned Q-matrix was',q_states[0].shape)
# Out:
# Completed 0 games, 1 rewards, 209 frames, score 0, max score 5
# Completed 1 games, 7 rewards, 1420 frames, score 5, max score 5
# Completed 2 games, 8 rewards, 1628 frames, score 0, max score 5
# Completed 3 games, 9 rewards, 1882 frames, score 0, max score 5
# Completed 4 games, 11 rewards, 2379 frames, score 1, max score 5
# Completed 5 games, 12 rewards, 2560 frames, score 0, max score 5
# Completed 6 games, 13 rewards, 2741 frames, score 0, max score 5
# Completed 7 games, 14 rewards, 2949 frames, score 0, max score 5
# Completed 8 games, 15 rewards, 3157 frames, score 0, max score 5
# Completed 9 games, 16 rewards, 3365 frames, score 0, max score 5
# Completed 10 games, 17 rewards, 3573 frames, score 0, max score 5
# Completed 11 games, 18 rewards, 3781 frames, score 0, max score 5
# Completed 12 games, 19 rewards, 3962 frames, score 0, max score 5
# Completed 13 games, 21 rewards, 4399 frames, score 1, max score 5
# Completed 14 games, 22 rewards, 4580 frames, score 0, max score 5
# Completed 15 games, 24 rewards, 4947 frames, score 1, max score 5
# Completed 16 games, 27 rewards, 5911 frames, score 2, max score 5
# Completed 17 games, 28 rewards, 6092 frames, score 0, max score 5
# Completed 18 games, 32 rewards, 7554 frames, score 3, max score 5
# Completed 19 games, 36 rewards, 8528 frames, score 3, max score 5
# Completed 20 games, 37 rewards, 8736 frames, score 0, max score 5
# Completed 21 games, 39 rewards, 9173 frames, score 1, max score 5
# Completed 22 games, 41 rewards, 9661 frames, score 1, max score 5
# Completed 23 games, 44 rewards, 10203 frames, score 2, max score 5
# Completed 24 games, 45 rewards, 10457 frames, score 0, max score 5
# Completed 25 games, 47 rewards, 10928 frames, score 1, max score 5
# Completed 26 games, 48 rewards, 11109 frames, score 0, max score 5
# Completed 27 games, 49 rewards, 11363 frames, score 0, max score 5
# Completed 28 games, 55 rewards, 12795 frames, score 5, max score 5
# Completed 29 games, 56 rewards, 13049 frames, score 0, max score 5
# Completed 30 games, 57 rewards, 13257 frames, score 0, max score 5
# Completed 31 games, 58 rewards, 13465 frames, score 0, max score 5
# Completed 32 games, 59 rewards, 13673 frames, score 0, max score 5
# Completed 33 games, 60 rewards, 13927 frames, score 0, max score 5
# Completed 34 games, 61 rewards, 14181 frames, score 0, max score 5
# Completed 35 games, 62 rewards, 14435 frames, score 0, max score 5
# Completed 36 games, 65 rewards, 15027 frames, score 2, max score 5
# Completed 37 games, 66 rewards, 15208 frames, score 0, max score 5
# Completed 38 games, 68 rewards, 15759 frames, score 1, max score 5
# Completed 39 games, 69 rewards, 15967 frames, score 0, max score 5
# Completed 40 games, 71 rewards, 16701 frames, score 1, max score 5
# Completed 41 games, 74 rewards, 17420 frames, score 2, max score 5
# Completed 42 games, 76 rewards, 17834 frames, score 1, max score 5
# Completed 43 games, 78 rewards, 18753 frames, score 1, max score 5
# Completed 44 games, 81 rewards, 19382 frames, score 2, max score 5
# Completed 45 games, 83 rewards, 19819 frames, score 1, max score 5
# Completed 46 games, 84 rewards, 20000 frames, score 0, max score 5
# Completed 47 games, 85 rewards, 20181 frames, score 0, max score 5
# Completed 48 games, 91 rewards, 21785 frames, score 5, max score 5
# Completed 49 games, 92 rewards, 21966 frames, score 0, max score 5
# Completed 50 games, 95 rewards, 23990 frames, score 2, max score 5
# Completed 51 games, 97 rewards, 24468 frames, score 1, max score 5
# Completed 52 games, 98 rewards, 24676 frames, score 0, max score 5
# Completed 53 games, 101 rewards, 25410 frames, score 2, max score 5
# Completed 54 games, 102 rewards, 25591 frames, score 0, max score 5
# Completed 55 games, 104 rewards, 26099 frames, score 1, max score 5
# Completed 56 games, 105 rewards, 26280 frames, score 0, max score 5
# Completed 57 games, 106 rewards, 26488 frames, score 0, max score 5
# Completed 58 games, 108 rewards, 26948 frames, score 1, max score 5
# Completed 59 games, 109 rewards, 27129 frames, score 0, max score 5
# Completed 60 games, 110 rewards, 27337 frames, score 0, max score 5
# Completed 61 games, 113 rewards, 27990 frames, score 2, max score 5
# Completed 62 games, 114 rewards, 28171 frames, score 0, max score 5
# Completed 63 games, 115 rewards, 28379 frames, score 0, max score 5
# Completed 64 games, 117 rewards, 29298 frames, score 1, max score 5
# Completed 65 games, 118 rewards, 29552 frames, score 0, max score 5
# Completed 66 games, 119 rewards, 29806 frames, score 0, max score 5
# Completed 67 games, 121 rewards, 30189 frames, score 1, max score 5
# Completed 68 games, 122 rewards, 30397 frames, score 0, max score 5
# Completed 69 games, 124 rewards, 30795 frames, score 1, max score 5
# Completed 70 games, 125 rewards, 31003 frames, score 0, max score 5
# Completed 71 games, 126 rewards, 31184 frames, score 0, max score 5
# Completed 72 games, 127 rewards, 31392 frames, score 0, max score 5
# Completed 73 games, 128 rewards, 31646 frames, score 0, max score 5
# Completed 74 games, 129 rewards, 31854 frames, score 0, max score 5
# Completed 75 games, 133 rewards, 32515 frames, score 3, max score 5
# Completed 76 games, 135 rewards, 32943 frames, score 1, max score 5
# Completed 77 games, 136 rewards, 33197 frames, score 0, max score 5
# Completed 78 games, 137 rewards, 33451 frames, score 0, max score 5
# Completed 79 games, 138 rewards, 33659 frames, score 0, max score 5
# Completed 80 games, 139 rewards, 33867 frames, score 0, max score 5
# Completed 81 games, 140 rewards, 34121 frames, score 0, max score 5
# Completed 82 games, 142 rewards, 34672 frames, score 1, max score 5
# Completed 83 games, 143 rewards, 34853 frames, score 0, max score 5
# Completed 84 games, 144 rewards, 35061 frames, score 0, max score 5
# Completed 85 games, 147 rewards, 35797 frames, score 2, max score 5
# Completed 86 games, 148 rewards, 36005 frames, score 0, max score 5
# Completed 87 games, 149 rewards, 36213 frames, score 0, max score 5
# Completed 88 games, 151 rewards, 36665 frames, score 1, max score 5
# Completed 89 games, 152 rewards, 36846 frames, score 0, max score 5
# Completed 90 games, 154 rewards, 37229 frames, score 1, max score 5
# Completed 91 games, 157 rewards, 37752 frames, score 2, max score 5
# Completed 92 games, 158 rewards, 38006 frames, score 0, max score 5
# Completed 93 games, 163 rewards, 38953 frames, score 4, max score 5
# Completed 94 games, 164 rewards, 39207 frames, score 0, max score 5
# Completed 95 games, 166 rewards, 39741 frames, score 1, max score 5
# Completed 96 games, 168 rewards, 40082 frames, score 1, max score 5
# Completed 97 games, 170 rewards, 40744 frames, score 1, max score 5
# Completed 98 games, 171 rewards, 40998 frames, score 0, max score 5
# Completed 99 games, 174 rewards, 41405 frames, score 2, max score 5
# Completed 100 games, 175 rewards, 41659 frames, score 0, max score 5
# Completed 101 games, 176 rewards, 41867 frames, score 0, max score 5
# Completed 102 games, 178 rewards, 42401 frames, score 1, max score 5
# Completed 103 games, 179 rewards, 42655 frames, score 0, max score 5
# Completed 104 games, 180 rewards, 42863 frames, score 0, max score 5
# Completed 105 games, 184 rewards, 43582 frames, score 3, max score 5
# Completed 106 games, 186 rewards, 43996 frames, score 1, max score 5
# Completed 107 games, 189 rewards, 45484 frames, score 2, max score 5
# Completed 108 games, 193 rewards, 46140 frames, score 3, max score 5
# Completed 109 games, 204 rewards, 48020 frames, score 10, max score 10
# Completed 110 games, 207 rewards, 48559 frames, score 2, max score 10
# Completed 111 games, 209 rewards, 49056 frames, score 1, max score 10
# Completed 112 games, 210 rewards, 49264 frames, score 0, max score 10
# Completed 113 games, 211 rewards, 49518 frames, score 0, max score 10
# Completed 114 games, 213 rewards, 49868 frames, score 1, max score 10
# Completed 115 games, 214 rewards, 50076 frames, score 0, max score 10
# Completed 116 games, 215 rewards, 50257 frames, score 0, max score 10
# Completed 117 games, 216 rewards, 50511 frames, score 0, max score 10
# Completed 118 games, 217 rewards, 50719 frames, score 0, max score 10
# Completed 119 games, 220 rewards, 51286 frames, score 2, max score 10
# Completed 120 games, 221 rewards, 51467 frames, score 0, max score 10
# Completed 121 games, 222 rewards, 51721 frames, score 0, max score 10
# Completed 122 games, 223 rewards, 51975 frames, score 0, max score 10
# Completed 123 games, 224 rewards, 52156 frames, score 0, max score 10
# Completed 124 games, 229 rewards, 53144 frames, score 4, max score 10
# Completed 125 games, 232 rewards, 54024 frames, score 2, max score 10
# Completed 126 games, 233 rewards, 54205 frames, score 0, max score 10
# Completed 127 games, 236 rewards, 54759 frames, score 2, max score 10
# Completed 128 games, 241 rewards, 55497 frames, score 4, max score 10
# Completed 129 games, 243 rewards, 56231 frames, score 1, max score 10
# Completed 130 games, 245 rewards, 56572 frames, score 1, max score 10
# Completed 131 games, 248 rewards, 57282 frames, score 2, max score 10
# Completed 132 games, 252 rewards, 58348 frames, score 3, max score 10
# Completed 133 games, 253 rewards, 58556 frames, score 0, max score 10
# Completed 134 games, 254 rewards, 58764 frames, score 0, max score 10
# Completed 135 games, 255 rewards, 58972 frames, score 0, max score 10
# Completed 136 games, 256 rewards, 59153 frames, score 0, max score 10
# Completed 137 games, 258 rewards, 59590 frames, score 1, max score 10
# Completed 138 games, 261 rewards, 60656 frames, score 2, max score 10
# Completed 139 games, 264 rewards, 61353 frames, score 2, max score 10
# Completed 140 games, 265 rewards, 61561 frames, score 0, max score 10
# Completed 141 games, 266 rewards, 61769 frames, score 0, max score 10
# Completed 142 games, 268 rewards, 62266 frames, score 1, max score 10
# Completed 143 games, 269 rewards, 62520 frames, score 0, max score 10
# Completed 144 games, 270 rewards, 62774 frames, score 0, max score 10
# Completed 145 games, 274 rewards, 63604 frames, score 3, max score 10
# Completed 146 games, 275 rewards, 63858 frames, score 0, max score 10
# Completed 147 games, 276 rewards, 64066 frames, score 0, max score 10
# Completed 148 games, 279 rewards, 64751 frames, score 2, max score 10
# Completed 149 games, 281 rewards, 65188 frames, score 1, max score 10
# Completed 150 games, 282 rewards, 65396 frames, score 0, max score 10
# Completed 151 games, 285 rewards, 66277 frames, score 2, max score 10
# Completed 152 games, 286 rewards, 66485 frames, score 0, max score 10
# Completed 153 games, 287 rewards, 66666 frames, score 0, max score 10
# Completed 154 games, 289 rewards, 67314 frames, score 1, max score 10
# Completed 155 games, 292 rewards, 67834 frames, score 2, max score 10
# Completed 156 games, 293 rewards, 68088 frames, score 0, max score 10
# Completed 157 games, 297 rewards, 68786 frames, score 3, max score 10
# Completed 158 games, 298 rewards, 69040 frames, score 0, max score 10
# Completed 159 games, 299 rewards, 69221 frames, score 0, max score 10
# Completed 160 games, 300 rewards, 69475 frames, score 0, max score 10
# Completed 161 games, 301 rewards, 69729 frames, score 0, max score 10
# Completed 162 games, 304 rewards, 70538 frames, score 2, max score 10
# Completed 163 games, 305 rewards, 70719 frames, score 0, max score 10
# Completed 164 games, 307 rewards, 71087 frames, score 1, max score 10
# Completed 165 games, 310 rewards, 71670 frames, score 2, max score 10
# Completed 166 games, 311 rewards, 71851 frames, score 0, max score 10
# Completed 167 games, 316 rewards, 73319 frames, score 4, max score 10
# Completed 168 games, 317 rewards, 73527 frames, score 0, max score 10
# Completed 169 games, 320 rewards, 74201 frames, score 2, max score 10
# Completed 170 games, 321 rewards, 74455 frames, score 0, max score 10
# Completed 171 games, 324 rewards, 75989 frames, score 2, max score 10
# Completed 172 games, 328 rewards, 77043 frames, score 3, max score 10
# Completed 173 games, 329 rewards, 77224 frames, score 0, max score 10
# Completed 174 games, 331 rewards, 77958 frames, score 1, max score 10
# Completed 175 games, 332 rewards, 78212 frames, score 0, max score 10
# Completed 176 games, 333 rewards, 78466 frames, score 0, max score 10
# Completed 177 games, 335 rewards, 78831 frames, score 1, max score 10
# Completed 178 games, 336 rewards, 79085 frames, score 0, max score 10
# Completed 179 games, 339 rewards, 80038 frames, score 2, max score 10
# Completed 180 games, 341 rewards, 80405 frames, score 1, max score 10
# Completed 181 games, 343 rewards, 80833 frames, score 1, max score 10
# Completed 182 games, 344 rewards, 81087 frames, score 0, max score 10
# Completed 183 games, 345 rewards, 81295 frames, score 0, max score 10
# Completed 184 games, 348 rewards, 81830 frames, score 2, max score 10
# Completed 185 games, 349 rewards, 82011 frames, score 0, max score 10
# Completed 186 games, 352 rewards, 83033 frames, score 2, max score 10
# Completed 187 games, 353 rewards, 83287 frames, score 0, max score 10
# Completed 188 games, 354 rewards, 83468 frames, score 0, max score 10
# Completed 189 games, 357 rewards, 84229 frames, score 2, max score 10
# Completed 190 games, 358 rewards, 84410 frames, score 0, max score 10
# Completed 191 games, 359 rewards, 84618 frames, score 0, max score 10
# Completed 192 games, 362 rewards, 85148 frames, score 2, max score 10
# Completed 193 games, 366 rewards, 85842 frames, score 3, max score 10
# Completed 194 games, 367 rewards, 86023 frames, score 0, max score 10
# Completed 195 games, 368 rewards, 86277 frames, score 0, max score 10
# Completed 196 games, 369 rewards, 86531 frames, score 0, max score 10
# Completed 197 games, 370 rewards, 86785 frames, score 0, max score 10
# Completed 198 games, 371 rewards, 86993 frames, score 0, max score 10
# Completed 199 games, 372 rewards, 87174 frames, score 0, max score 10
# Completed 200 games, 373 rewards, 87355 frames, score 0, max score 10
# Completed 201 games, 375 rewards, 87769 frames, score 1, max score 10
# Completed 202 games, 376 rewards, 87977 frames, score 0, max score 10
# Completed 203 games, 377 rewards, 88158 frames, score 0, max score 10
# Completed 204 games, 379 rewards, 88510 frames, score 1, max score 10
# Completed 205 games, 380 rewards, 88764 frames, score 0, max score 10
# Completed 206 games, 382 rewards, 89178 frames, score 1, max score 10
# Completed 207 games, 383 rewards, 89386 frames, score 0, max score 10
# Completed 208 games, 385 rewards, 89792 frames, score 1, max score 10
# Completed 209 games, 387 rewards, 90343 frames, score 1, max score 10
# Completed 210 games, 388 rewards, 90597 frames, score 0, max score 10
# Completed 211 games, 389 rewards, 90805 frames, score 0, max score 10
# Completed 212 games, 392 rewards, 91416 frames, score 2, max score 10
# Completed 213 games, 395 rewards, 92181 frames, score 2, max score 10
# Completed 214 games, 396 rewards, 92362 frames, score 0, max score 10
# Completed 215 games, 399 rewards, 93054 frames, score 2, max score 10
# Completed 216 games, 401 rewards, 93533 frames, score 1, max score 10
# Completed 217 games, 402 rewards, 93787 frames, score 0, max score 10
# Completed 218 games, 403 rewards, 93968 frames, score 0, max score 10
# Completed 219 games, 405 rewards, 94519 frames, score 1, max score 10
# Completed 220 games, 406 rewards, 94773 frames, score 0, max score 10
# Completed 221 games, 408 rewards, 95141 frames, score 1, max score 10
# Completed 222 games, 410 rewards, 95578 frames, score 1, max score 10
# Completed 223 games, 411 rewards, 95786 frames, score 0, max score 10
# Completed 224 games, 412 rewards, 95994 frames, score 0, max score 10
# Completed 225 games, 421 rewards, 98211 frames, score 8, max score 10
# Completed 226 games, 422 rewards, 98465 frames, score 0, max score 10
# Completed 227 games, 424 rewards, 99067 frames, score 1, max score 10
# Completed 228 games, 427 rewards, 99558 frames, score 2, max score 10
# Completed 229 games, 428 rewards, 99739 frames, score 0, max score 10
# Completed 230 games, 431 rewards, 100777 frames, score 2, max score 10
# Completed 231 games, 432 rewards, 100958 frames, score 0, max score 10
# Completed 232 games, 436 rewards, 101810 frames, score 3, max score 10
# Completed 233 games, 438 rewards, 102400 frames, score 1, max score 10
# Completed 234 games, 441 rewards, 103273 frames, score 2, max score 10
# Completed 235 games, 443 rewards, 103641 frames, score 1, max score 10
# Completed 236 games, 444 rewards, 103895 frames, score 0, max score 10
# Completed 237 games, 447 rewards, 104719 frames, score 2, max score 10
# Completed 238 games, 448 rewards, 104927 frames, score 0, max score 10
# Completed 239 games, 449 rewards, 105181 frames, score 0, max score 10
# Completed 240 games, 452 rewards, 105550 frames, score 2, max score 10
# Completed 241 games, 453 rewards, 105758 frames, score 0, max score 10
# Completed 242 games, 460 rewards, 107190 frames, score 6, max score 10
# Completed 243 games, 462 rewards, 107604 frames, score 1, max score 10
# Completed 244 games, 463 rewards, 107812 frames, score 0, max score 10
# Completed 245 games, 464 rewards, 108066 frames, score 0, max score 10
# Completed 246 games, 469 rewards, 109285 frames, score 4, max score 10
# Completed 247 games, 471 rewards, 109793 frames, score 1, max score 10
# Completed 248 games, 472 rewards, 110047 frames, score 0, max score 10
# Completed 249 games, 477 rewards, 111461 frames, score 4, max score 10
# Completed 250 games, 485 rewards, 113050 frames, score 7, max score 10
# Completed 251 games, 487 rewards, 113456 frames, score 1, max score 10
# Completed 252 games, 488 rewards, 113637 frames, score 0, max score 10
# Completed 253 games, 489 rewards, 113845 frames, score 0, max score 10
# Completed 254 games, 490 rewards, 114026 frames, score 0, max score 10
# Completed 255 games, 492 rewards, 114760 frames, score 1, max score 10
# Completed 256 games, 496 rewards, 115797 frames, score 3, max score 10
# Completed 257 games, 499 rewards, 116588 frames, score 2, max score 10
# Completed 258 games, 501 rewards, 117076 frames, score 1, max score 10
# Completed 259 games, 503 rewards, 117444 frames, score 1, max score 10
# Completed 260 games, 506 rewards, 118059 frames, score 2, max score 10
# Completed 261 games, 508 rewards, 118470 frames, score 1, max score 10
# Completed 262 games, 511 rewards, 119128 frames, score 2, max score 10
# Completed 263 games, 513 rewards, 119480 frames, score 1, max score 10
# Completed 264 games, 518 rewards, 120479 frames, score 4, max score 10
# Completed 265 games, 520 rewards, 120847 frames, score 1, max score 10
# Completed 266 games, 521 rewards, 121101 frames, score 0, max score 10
# Completed 267 games, 523 rewards, 121835 frames, score 1, max score 10
# Completed 268 games, 529 rewards, 122830 frames, score 5, max score 10
# Completed 269 games, 530 rewards, 123084 frames, score 0, max score 10
# Completed 270 games, 531 rewards, 123338 frames, score 0, max score 10
# Completed 271 games, 532 rewards, 123592 frames, score 0, max score 10
# Completed 272 games, 538 rewards, 124749 frames, score 5, max score 10
# Completed 273 games, 540 rewards, 125246 frames, score 1, max score 10
# Completed 274 games, 541 rewards, 125454 frames, score 0, max score 10
# Completed 275 games, 542 rewards, 125635 frames, score 0, max score 10
# Completed 276 games, 543 rewards, 125843 frames, score 0, max score 10
# Completed 277 games, 544 rewards, 126024 frames, score 0, max score 10
# Completed 278 games, 545 rewards, 126232 frames, score 0, max score 10
# Completed 279 games, 548 rewards, 126671 frames, score 2, max score 10
# Completed 280 games, 550 rewards, 127134 frames, score 1, max score 10
# Completed 281 games, 553 rewards, 127825 frames, score 2, max score 10
# Completed 282 games, 561 rewards, 129069 frames, score 7, max score 10
# Completed 283 games, 563 rewards, 129436 frames, score 1, max score 10
# Completed 284 games, 564 rewards, 129617 frames, score 0, max score 10
# Completed 285 games, 566 rewards, 130051 frames, score 1, max score 10
# Completed 286 games, 569 rewards, 132075 frames, score 2, max score 10
# Completed 287 games, 570 rewards, 132329 frames, score 0, max score 10
# Completed 288 games, 573 rewards, 132868 frames, score 2, max score 10
# Completed 289 games, 574 rewards, 133076 frames, score 0, max score 10
# Completed 290 games, 577 rewards, 134087 frames, score 2, max score 10
# Completed 291 games, 580 rewards, 134777 frames, score 2, max score 10
# Completed 292 games, 586 rewards, 135726 frames, score 5, max score 10
# Completed 293 games, 589 rewards, 136748 frames, score 2, max score 10
# Completed 294 games, 590 rewards, 136929 frames, score 0, max score 10
# Completed 295 games, 600 rewards, 139074 frames, score 9, max score 10
# Completed 296 games, 607 rewards, 140634 frames, score 6, max score 10
# Completed 297 games, 615 rewards, 142371 frames, score 7, max score 10
# Completed 298 games, 616 rewards, 142552 frames, score 0, max score 10
# Completed 299 games, 617 rewards, 142733 frames, score 0, max score 10
# Completed 300 games, 618 rewards, 142941 frames, score 0, max score 10
# Completed 301 games, 622 rewards, 144023 frames, score 3, max score 10
# Completed 302 games, 623 rewards, 144277 frames, score 0, max score 10
# Completed 303 games, 624 rewards, 144531 frames, score 0, max score 10
# Completed 304 games, 625 rewards, 144785 frames, score 0, max score 10
# Completed 305 games, 626 rewards, 145039 frames, score 0, max score 10
# Completed 306 games, 629 rewards, 145519 frames, score 2, max score 10
# Completed 307 games, 630 rewards, 145700 frames, score 0, max score 10
# Completed 308 games, 631 rewards, 145954 frames, score 0, max score 10
# Completed 309 games, 632 rewards, 146135 frames, score 0, max score 10
# Completed 310 games, 633 rewards, 146316 frames, score 0, max score 10
# Completed 311 games, 636 rewards, 147180 frames, score 2, max score 10
# Completed 312 games, 639 rewards, 147882 frames, score 2, max score 10
# Completed 313 games, 640 rewards, 148136 frames, score 0, max score 10
# Completed 314 games, 642 rewards, 148670 frames, score 1, max score 10
# Completed 315 games, 643 rewards, 148924 frames, score 0, max score 10
# Completed 316 games, 644 rewards, 149132 frames, score 0, max score 10
# Completed 317 games, 645 rewards, 149386 frames, score 0, max score 10
# Completed 318 games, 648 rewards, 149941 frames, score 2, max score 10
# Completed 319 games, 652 rewards, 150649 frames, score 3, max score 10
# Completed 320 games, 659 rewards, 151726 frames, score 6, max score 10
# Completed 321 games, 661 rewards, 152124 frames, score 1, max score 10
# Completed 322 games, 664 rewards, 152640 frames, score 2, max score 10
# Completed 323 games, 665 rewards, 152894 frames, score 0, max score 10
# Completed 324 games, 670 rewards, 155680 frames, score 4, max score 10
# Completed 325 games, 672 rewards, 156177 frames, score 1, max score 10
# Completed 326 games, 673 rewards, 156431 frames, score 0, max score 10
# Completed 327 games, 675 rewards, 156928 frames, score 1, max score 10
# Completed 328 games, 678 rewards, 157830 frames, score 2, max score 10
# Completed 329 games, 681 rewards, 158471 frames, score 2, max score 10
# Completed 330 games, 683 rewards, 158908 frames, score 1, max score 10
# Completed 331 games, 684 rewards, 159116 frames, score 0, max score 10
# Completed 332 games, 685 rewards, 159297 frames, score 0, max score 10
# Completed 333 games, 686 rewards, 159551 frames, score 0, max score 10
# Completed 334 games, 688 rewards, 159918 frames, score 1, max score 10
# Completed 335 games, 691 rewards, 160409 frames, score 2, max score 10
# Completed 336 games, 695 rewards, 161193 frames, score 3, max score 10
# Completed 337 games, 699 rewards, 162061 frames, score 3, max score 10
# Completed 338 games, 706 rewards, 163174 frames, score 6, max score 10
# Completed 339 games, 708 rewards, 163640 frames, score 1, max score 10
# Completed 340 games, 709 rewards, 163894 frames, score 0, max score 10
# Completed 341 games, 711 rewards, 164357 frames, score 1, max score 10
# Completed 342 games, 712 rewards, 164611 frames, score 0, max score 10
# Completed 343 games, 714 rewards, 165009 frames, score 1, max score 10
# Completed 344 games, 716 rewards, 165671 frames, score 1, max score 10
# Completed 345 games, 718 rewards, 166012 frames, score 1, max score 10
# Completed 346 games, 719 rewards, 166220 frames, score 0, max score 10
# Completed 347 games, 722 rewards, 166917 frames, score 2, max score 10
# Completed 348 games, 726 rewards, 167676 frames, score 3, max score 10
# Completed 349 games, 728 rewards, 168188 frames, score 1, max score 10
# Completed 350 games, 729 rewards, 168442 frames, score 0, max score 10
# Completed 351 games, 731 rewards, 168879 frames, score 1, max score 10
# Completed 352 games, 733 rewards, 169367 frames, score 1, max score 10
# Completed 353 games, 734 rewards, 169621 frames, score 0, max score 10
# Completed 354 games, 735 rewards, 169875 frames, score 0, max score 10
# Completed 355 games, 739 rewards, 170517 frames, score 3, max score 10
# Completed 356 games, 741 rewards, 170954 frames, score 1, max score 10
# Completed 357 games, 742 rewards, 171162 frames, score 0, max score 10
# Completed 358 games, 743 rewards, 171343 frames, score 0, max score 10
# Completed 359 games, 745 rewards, 171777 frames, score 1, max score 10
# Completed 360 games, 746 rewards, 171985 frames, score 0, max score 10
# Completed 361 games, 749 rewards, 172489 frames, score 2, max score 10
# Completed 362 games, 751 rewards, 173408 frames, score 1, max score 10
# Completed 363 games, 754 rewards, 174518 frames, score 2, max score 10
# Completed 364 games, 757 rewards, 175198 frames, score 2, max score 10
# Completed 365 games, 763 rewards, 176470 frames, score 5, max score 10
# Completed 366 games, 765 rewards, 176853 frames, score 1, max score 10
# Completed 367 games, 769 rewards, 177761 frames, score 3, max score 10
# Completed 368 games, 780 rewards, 180563 frames, score 10, max score 10
# Completed 369 games, 781 rewards, 180817 frames, score 0, max score 10
# Completed 370 games, 785 rewards, 181725 frames, score 3, max score 10
# Completed 371 games, 787 rewards, 182315 frames, score 1, max score 10
# Completed 372 games, 790 rewards, 182913 frames, score 2, max score 10
# Completed 373 games, 791 rewards, 183167 frames, score 0, max score 10
# Completed 374 games, 794 rewards, 183926 frames, score 2, max score 10
# Completed 375 games, 797 rewards, 184406 frames, score 2, max score 10
# Completed 376 games, 801 rewards, 185318 frames, score 3, max score 10
# Completed 377 games, 802 rewards, 185526 frames, score 0, max score 10
# Completed 378 games, 803 rewards, 185707 frames, score 0, max score 10
# Completed 379 games, 804 rewards, 185888 frames, score 0, max score 10
# Completed 380 games, 810 rewards, 190261 frames, score 5, max score 10
# Completed 381 games, 811 rewards, 190515 frames, score 0, max score 10
# Completed 382 games, 813 rewards, 190920 frames, score 1, max score 10
# Completed 383 games, 815 rewards, 191654 frames, score 1, max score 10
# Completed 384 games, 816 rewards, 191908 frames, score 0, max score 10
# Completed 385 games, 818 rewards, 192570 frames, score 1, max score 10
# Completed 386 games, 819 rewards, 192751 frames, score 0, max score 10
# Completed 387 games, 820 rewards, 193005 frames, score 0, max score 10
# Completed 388 games, 821 rewards, 193259 frames, score 0, max score 10
# Completed 389 games, 825 rewards, 194013 frames, score 3, max score 10
# Completed 390 games, 826 rewards, 194194 frames, score 0, max score 10
# Completed 391 games, 830 rewards, 195371 frames, score 3, max score 10
# Completed 392 games, 831 rewards, 195552 frames, score 0, max score 10
# Completed 393 games, 835 rewards, 197049 frames, score 3, max score 10
# Completed 394 games, 837 rewards, 197583 frames, score 1, max score 10
# Completed 395 games, 838 rewards, 197837 frames, score 0, max score 10
# Completed 396 games, 839 rewards, 198018 frames, score 0, max score 10
# Completed 397 games, 840 rewards, 198272 frames, score 0, max score 10
# Completed 398 games, 841 rewards, 198453 frames, score 0, max score 10
# Completed 399 games, 842 rewards, 198707 frames, score 0, max score 10
# Completed 400 games, 844 rewards, 199141 frames, score 1, max score 10
# Completed 401 games, 845 rewards, 199395 frames, score 0, max score 10
# Completed 402 games, 846 rewards, 199649 frames, score 0, max score 10
# Completed 403 games, 847 rewards, 199903 frames, score 0, max score 10
# Completed 404 games, 848 rewards, 200157 frames, score 0, max score 10
# Completed 405 games, 855 rewards, 202171 frames, score 6, max score 10
# Completed 406 games, 856 rewards, 202425 frames, score 0, max score 10
# Completed 407 games, 857 rewards, 202679 frames, score 0, max score 10
# Completed 408 games, 860 rewards, 203406 frames, score 2, max score 10
# Completed 409 games, 862 rewards, 203996 frames, score 1, max score 10
# Completed 410 games, 864 rewards, 204493 frames, score 1, max score 10
# Completed 411 games, 867 rewards, 205593 frames, score 2, max score 10
# Completed 412 games, 871 rewards, 206289 frames, score 3, max score 10
# Completed 413 games, 872 rewards, 206470 frames, score 0, max score 10
# Completed 414 games, 876 rewards, 207302 frames, score 3, max score 10
# Completed 415 games, 879 rewards, 207856 frames, score 2, max score 10
# Completed 416 games, 880 rewards, 208037 frames, score 0, max score 10
# Completed 417 games, 883 rewards, 208874 frames, score 2, max score 10
# Completed 418 games, 884 rewards, 209128 frames, score 0, max score 10
# Completed 419 games, 885 rewards, 209382 frames, score 0, max score 10
# Completed 420 games, 887 rewards, 209870 frames, score 1, max score 10
# Completed 421 games, 889 rewards, 210307 frames, score 1, max score 10
# Completed 422 games, 890 rewards, 210488 frames, score 0, max score 10
# Completed 423 games, 893 rewards, 211369 frames, score 2, max score 10
# Completed 424 games, 894 rewards, 211550 frames, score 0, max score 10
# Completed 425 games, 902 rewards, 213013 frames, score 7, max score 10
# Completed 426 games, 909 rewards, 216093 frames, score 6, max score 10
# Completed 427 games, 912 rewards, 216792 frames, score 2, max score 10
# Completed 428 games, 915 rewards, 217562 frames, score 2, max score 10
# Completed 429 games, 917 rewards, 218033 frames, score 1, max score 10
# Completed 430 games, 918 rewards, 218287 frames, score 0, max score 10
# Completed 431 games, 919 rewards, 218541 frames, score 0, max score 10
# Completed 432 games, 920 rewards, 218795 frames, score 0, max score 10
# Completed 433 games, 926 rewards, 219856 frames, score 5, max score 10
# Completed 434 games, 931 rewards, 221091 frames, score 4, max score 10
# Completed 435 games, 932 rewards, 221299 frames, score 0, max score 10
# Completed 436 games, 934 rewards, 221686 frames, score 1, max score 10
# Completed 437 games, 936 rewards, 222183 frames, score 1, max score 10
# Completed 438 games, 938 rewards, 222566 frames, score 1, max score 10
# Completed 439 games, 940 rewards, 223078 frames, score 1, max score 10
# Completed 440 games, 943 rewards, 223623 frames, score 2, max score 10
# Completed 441 games, 946 rewards, 224170 frames, score 2, max score 10
# Completed 442 games, 947 rewards, 224351 frames, score 0, max score 10
# Completed 443 games, 949 rewards, 224822 frames, score 1, max score 10
# Completed 444 games, 951 rewards, 225205 frames, score 1, max score 10
# Completed 445 games, 953 rewards, 225795 frames, score 1, max score 10
# Completed 446 games, 954 rewards, 225976 frames, score 0, max score 10
# Completed 447 games, 958 rewards, 226914 frames, score 3, max score 10
# Completed 448 games, 963 rewards, 228285 frames, score 4, max score 10
# Completed 449 games, 964 rewards, 228493 frames, score 0, max score 10
# Completed 450 games, 965 rewards, 228701 frames, score 0, max score 10
# Completed 451 games, 969 rewards, 230235 frames, score 3, max score 10
# Completed 452 games, 970 rewards, 230416 frames, score 0, max score 10
# Completed 453 games, 972 rewards, 230853 frames, score 1, max score 10
# Completed 454 games, 974 rewards, 231249 frames, score 1, max score 10
# Completed 455 games, 979 rewards, 232812 frames, score 4, max score 10
# Completed 456 games, 981 rewards, 233275 frames, score 1, max score 10
# Completed 457 games, 982 rewards, 233483 frames, score 0, max score 10
# Completed 458 games, 986 rewards, 234275 frames, score 3, max score 10
# Completed 459 games, 987 rewards, 234529 frames, score 0, max score 10
# Completed 460 games, 989 rewards, 234957 frames, score 1, max score 10
# Completed 461 games, 991 rewards, 235417 frames, score 1, max score 10
# Completed 462 games, 992 rewards, 235598 frames, score 0, max score 10
# Completed 463 games, 994 rewards, 236246 frames, score 1, max score 10
# Completed 464 games, 997 rewards, 236893 frames, score 2, max score 10
# Completed 465 games, 999 rewards, 237555 frames, score 1, max score 10
# Completed 466 games, 1000 rewards, 237763 frames, score 0, max score 10
# Completed 467 games, 1004 rewards, 238676 frames, score 3, max score 10
# Completed 468 games, 1007 rewards, 239524 frames, score 2, max score 10
# Completed 469 games, 1009 rewards, 239938 frames, score 1, max score 10
# Completed 470 games, 1011 rewards, 240450 frames, score 1, max score 10
# Completed 471 games, 1013 rewards, 240947 frames, score 1, max score 10
# Completed 472 games, 1014 rewards, 241201 frames, score 0, max score 10
# Completed 473 games, 1020 rewards, 242169 frames, score 5, max score 10
# Completed 474 games, 1022 rewards, 242817 frames, score 1, max score 10
# Completed 475 games, 1023 rewards, 242998 frames, score 0, max score 10
# Completed 476 games, 1027 rewards, 244224 frames, score 3, max score 10
# Completed 477 games, 1028 rewards, 244478 frames, score 0, max score 10
# Completed 478 games, 1029 rewards, 244732 frames, score 0, max score 10
# Completed 479 games, 1031 rewards, 245192 frames, score 1, max score 10
# Completed 480 games, 1035 rewards, 246182 frames, score 3, max score 10
# Completed 481 games, 1038 rewards, 246783 frames, score 2, max score 10
# Completed 482 games, 1041 rewards, 247532 frames, score 2, max score 10
# Completed 483 games, 1042 rewards, 247713 frames, score 0, max score 10
# Completed 484 games, 1044 rewards, 248118 frames, score 1, max score 10
# Completed 485 games, 1046 rewards, 248780 frames, score 1, max score 10
# Completed 486 games, 1049 rewards, 249319 frames, score 2, max score 10
# Completed 487 games, 1050 rewards, 249527 frames, score 0, max score 10
# Completed 488 games, 1052 rewards, 249932 frames, score 1, max score 10
# Completed 489 games, 1056 rewards, 250778 frames, score 3, max score 10
# Completed 490 games, 1063 rewards, 252074 frames, score 6, max score 10
# Completed 491 games, 1064 rewards, 252282 frames, score 0, max score 10
# Completed 492 games, 1065 rewards, 252463 frames, score 0, max score 10
# Completed 493 games, 1066 rewards, 252671 frames, score 0, max score 10
# Completed 494 games, 1068 rewards, 253054 frames, score 1, max score 10
# Completed 495 games, 1071 rewards, 253695 frames, score 2, max score 10
# Completed 496 games, 1073 rewards, 254207 frames, score 1, max score 10
# Completed 497 games, 1078 rewards, 255000 frames, score 4, max score 10
# Completed 498 games, 1079 rewards, 255254 frames, score 0, max score 10
# Completed 499 games, 1082 rewards, 255852 frames, score 2, max score 10
# Completed 500 games, 1084 rewards, 256204 frames, score 1, max score 10
# Completed 501 games, 1093 rewards, 257615 frames, score 8, max score 10
# Completed 502 games, 1094 rewards, 257869 frames, score 0, max score 10
# Completed 503 games, 1096 rewards, 258603 frames, score 1, max score 10
# Completed 504 games, 1098 rewards, 258944 frames, score 1, max score 10
# Completed 505 games, 1100 rewards, 259606 frames, score 1, max score 10
# Completed 506 games, 1106 rewards, 260686 frames, score 5, max score 10
# Completed 507 games, 1107 rewards, 260940 frames, score 0, max score 10
# Completed 508 games, 1108 rewards, 261148 frames, score 0, max score 10
# Completed 509 games, 1111 rewards, 261851 frames, score 2, max score 10
# Completed 510 games, 1112 rewards, 262059 frames, score 0, max score 10
# Completed 511 games, 1113 rewards, 262267 frames, score 0, max score 10
# Completed 512 games, 1114 rewards, 262475 frames, score 0, max score 10
# Completed 513 games, 1115 rewards, 262683 frames, score 0, max score 10
# Completed 514 games, 1116 rewards, 262891 frames, score 0, max score 10
# Completed 515 games, 1120 rewards, 263519 frames, score 3, max score 10
# Completed 516 games, 1122 rewards, 263917 frames, score 1, max score 10
# Completed 517 games, 1126 rewards, 264599 frames, score 3, max score 10
# Completed 518 games, 1127 rewards, 264780 frames, score 0, max score 10
# Completed 519 games, 1131 rewards, 265803 frames, score 3, max score 10
# Completed 520 games, 1132 rewards, 266011 frames, score 0, max score 10
# Completed 521 games, 1135 rewards, 266728 frames, score 2, max score 10
# Completed 522 games, 1136 rewards, 266982 frames, score 0, max score 10
# Completed 523 games, 1137 rewards, 267236 frames, score 0, max score 10
# Completed 524 games, 1140 rewards, 268175 frames, score 2, max score 10
# Completed 525 games, 1141 rewards, 268356 frames, score 0, max score 10
# Completed 526 games, 1144 rewards, 269310 frames, score 2, max score 10
# Completed 527 games, 1147 rewards, 269797 frames, score 2, max score 10
# Completed 528 games, 1150 rewards, 271172 frames, score 2, max score 10
# Completed 529 games, 1153 rewards, 271974 frames, score 2, max score 10
# Completed 530 games, 1158 rewards, 273304 frames, score 4, max score 10
# Completed 531 games, 1159 rewards, 273558 frames, score 0, max score 10
# Completed 532 games, 1161 rewards, 273899 frames, score 1, max score 10
# Completed 533 games, 1163 rewards, 274305 frames, score 1, max score 10
# Completed 534 games, 1169 rewards, 276025 frames, score 5, max score 10
# Completed 535 games, 1170 rewards, 276279 frames, score 0, max score 10
# Completed 536 games, 1171 rewards, 276533 frames, score 0, max score 10
# Completed 537 games, 1173 rewards, 277030 frames, score 1, max score 10
# Completed 538 games, 1175 rewards, 277467 frames, score 1, max score 10
# Completed 539 games, 1177 rewards, 278069 frames, score 1, max score 10
# Completed 540 games, 1178 rewards, 278323 frames, score 0, max score 10
# Completed 541 games, 1180 rewards, 278985 frames, score 1, max score 10
# Completed 542 games, 1187 rewards, 280188 frames, score 6, max score 10
# Completed 543 games, 1188 rewards, 280369 frames, score 0, max score 10
# Completed 544 games, 1191 rewards, 281004 frames, score 2, max score 10
# Completed 545 games, 1192 rewards, 281212 frames, score 0, max score 10
# Completed 546 games, 1194 rewards, 281946 frames, score 1, max score 10
# Completed 547 games, 1196 rewards, 282298 frames, score 1, max score 10
# Completed 548 games, 1198 rewards, 282960 frames, score 1, max score 10
# Completed 549 games, 1203 rewards, 283934 frames, score 4, max score 10
# Completed 550 games, 1204 rewards, 284115 frames, score 0, max score 10
# Completed 551 games, 1207 rewards, 284690 frames, score 2, max score 10
# Completed 552 games, 1208 rewards, 284944 frames, score 0, max score 10
# Completed 553 games, 1209 rewards, 285198 frames, score 0, max score 10
# Completed 554 games, 1212 rewards, 285775 frames, score 2, max score 10
# Completed 555 games, 1213 rewards, 286029 frames, score 0, max score 10
# Completed 556 games, 1215 rewards, 286517 frames, score 1, max score 10
# Completed 557 games, 1218 rewards, 287209 frames, score 2, max score 10
# Completed 558 games, 1220 rewards, 287669 frames, score 1, max score 10
# Completed 559 games, 1221 rewards, 287850 frames, score 0, max score 10
# Completed 560 games, 1222 rewards, 288058 frames, score 0, max score 10
# Completed 561 games, 1225 rewards, 288755 frames, score 2, max score 10
# Completed 562 games, 1226 rewards, 288963 frames, score 0, max score 10
# Completed 563 games, 1230 rewards, 290498 frames, score 3, max score 10
# Completed 564 games, 1231 rewards, 290679 frames, score 0, max score 10
# Completed 565 games, 1233 rewards, 291269 frames, score 1, max score 10
# Completed 566 games, 1238 rewards, 292511 frames, score 4, max score 10
# Completed 567 games, 1239 rewards, 292765 frames, score 0, max score 10
# Completed 568 games, 1241 rewards, 293179 frames, score 1, max score 10
# Completed 569 games, 1243 rewards, 293676 frames, score 1, max score 10
# Completed 570 games, 1248 rewards, 294759 frames, score 4, max score 10
# Completed 571 games, 1249 rewards, 294967 frames, score 0, max score 10
# Completed 572 games, 1250 rewards, 295221 frames, score 0, max score 10
# Completed 573 games, 1251 rewards, 295475 frames, score 0, max score 10
# Completed 574 games, 1258 rewards, 296556 frames, score 6, max score 10
# Completed 575 games, 1260 rewards, 297053 frames, score 1, max score 10
# Completed 576 games, 1261 rewards, 297234 frames, score 0, max score 10
# Completed 577 games, 1264 rewards, 297822 frames, score 2, max score 10
# Completed 578 games, 1265 rewards, 298030 frames, score 0, max score 10
# Completed 579 games, 1267 rewards, 298371 frames, score 1, max score 10
# Completed 580 games, 1269 rewards, 298842 frames, score 1, max score 10
# Completed 581 games, 1273 rewards, 300069 frames, score 3, max score 10
# Completed 582 games, 1274 rewards, 300250 frames, score 0, max score 10
# Completed 583 games, 1276 rewards, 300602 frames, score 1, max score 10
# Completed 584 games, 1277 rewards, 300783 frames, score 0, max score 10
# Completed 585 games, 1280 rewards, 301679 frames, score 2, max score 10
# Completed 586 games, 1281 rewards, 301887 frames, score 0, max score 10
# Completed 587 games, 1283 rewards, 302252 frames, score 1, max score 10
# Completed 588 games, 1287 rewards, 303034 frames, score 3, max score 10
# Completed 589 games, 1288 rewards, 303242 frames, score 0, max score 10
# Completed 590 games, 1289 rewards, 303450 frames, score 0, max score 10
# Completed 591 games, 1292 rewards, 304274 frames, score 2, max score 10
# Completed 592 games, 1297 rewards, 305179 frames, score 4, max score 10
# Completed 593 games, 1304 rewards, 306409 frames, score 6, max score 10
# Completed 594 games, 1307 rewards, 307105 frames, score 2, max score 10
# Completed 595 games, 1311 rewards, 308682 frames, score 3, max score 10
# Completed 596 games, 1312 rewards, 308890 frames, score 0, max score 10
# Completed 597 games, 1313 rewards, 309098 frames, score 0, max score 10
# Completed 598 games, 1314 rewards, 309279 frames, score 0, max score 10
# Completed 599 games, 1315 rewards, 309487 frames, score 0, max score 10
# Completed 600 games, 1319 rewards, 310402 frames, score 3, max score 10
# Completed 601 games, 1320 rewards, 310583 frames, score 0, max score 10
# Completed 602 games, 1322 rewards, 310935 frames, score 1, max score 10
# Completed 603 games, 1324 rewards, 311537 frames, score 1, max score 10
# Completed 604 games, 1325 rewards, 311718 frames, score 0, max score 10
# Completed 605 games, 1328 rewards, 312265 frames, score 2, max score 10
# Completed 606 games, 1329 rewards, 312473 frames, score 0, max score 10
# Completed 607 games, 1330 rewards, 312654 frames, score 0, max score 10
# Completed 608 games, 1331 rewards, 312862 frames, score 0, max score 10
# Completed 609 games, 1332 rewards, 313116 frames, score 0, max score 10
# Completed 610 games, 1333 rewards, 313324 frames, score 0, max score 10
# Completed 611 games, 1336 rewards, 314055 frames, score 2, max score 10
# Completed 612 games, 1342 rewards, 316318 frames, score 5, max score 10
# Completed 613 games, 1344 rewards, 316746 frames, score 1, max score 10
# Completed 614 games, 1349 rewards, 319085 frames, score 4, max score 10
# Completed 615 games, 1352 rewards, 320732 frames, score 2, max score 10
# Completed 616 games, 1353 rewards, 320913 frames, score 0, max score 10
# Completed 617 games, 1355 rewards, 321575 frames, score 1, max score 10
# Completed 618 games, 1356 rewards, 321829 frames, score 0, max score 10
# Completed 619 games, 1357 rewards, 322083 frames, score 0, max score 10
# Completed 620 games, 1358 rewards, 322337 frames, score 0, max score 10
# Completed 621 games, 1362 rewards, 323123 frames, score 3, max score 10
# Completed 622 games, 1363 rewards, 323304 frames, score 0, max score 10
# Completed 623 games, 1371 rewards, 324713 frames, score 7, max score 10
# Completed 624 games, 1372 rewards, 324894 frames, score 0, max score 10
# Completed 625 games, 1373 rewards, 325148 frames, score 0, max score 10
# Completed 626 games, 1375 rewards, 325750 frames, score 1, max score 10
# Completed 627 games, 1376 rewards, 325958 frames, score 0, max score 10
# Completed 628 games, 1377 rewards, 326166 frames, score 0, max score 10
# Completed 629 games, 1378 rewards, 326420 frames, score 0, max score 10
# Completed 630 games, 1379 rewards, 326674 frames, score 0, max score 10
# Completed 631 games, 1380 rewards, 326882 frames, score 0, max score 10
# Completed 632 games, 1381 rewards, 327136 frames, score 0, max score 10
# Completed 633 games, 1383 rewards, 327726 frames, score 1, max score 10
# Completed 634 games, 1384 rewards, 327907 frames, score 0, max score 10
# Completed 635 games, 1385 rewards, 328161 frames, score 0, max score 10
# Completed 636 games, 1390 rewards, 330597 frames, score 4, max score 10
# Completed 637 games, 1392 rewards, 331094 frames, score 1, max score 10
# Completed 638 games, 1395 rewards, 331773 frames, score 2, max score 10
# Completed 639 games, 1397 rewards, 332114 frames, score 1, max score 10
# Completed 640 games, 1400 rewards, 332821 frames, score 2, max score 10
# Completed 641 games, 1405 rewards, 333975 frames, score 4, max score 10
# Completed 642 games, 1408 rewards, 334628 frames, score 2, max score 10
# Completed 643 games, 1409 rewards, 334882 frames, score 0, max score 10
# Completed 644 games, 1413 rewards, 336032 frames, score 3, max score 10
# Completed 645 games, 1416 rewards, 336724 frames, score 2, max score 10
# Completed 646 games, 1418 rewards, 337107 frames, score 1, max score 10
# Completed 647 games, 1419 rewards, 337288 frames, score 0, max score 10
# Completed 648 games, 1425 rewards, 338151 frames, score 5, max score 10
# Completed 649 games, 1426 rewards, 338359 frames, score 0, max score 10
# Completed 650 games, 1427 rewards, 338540 frames, score 0, max score 10
# Completed 651 games, 1439 rewards, 342957 frames, score 11, max score 11
# Completed 652 games, 1445 rewards, 343913 frames, score 5, max score 11
# Completed 653 games, 1447 rewards, 344350 frames, score 1, max score 11
# Completed 654 games, 1449 rewards, 344901 frames, score 1, max score 11
# Completed 655 games, 1450 rewards, 345109 frames, score 0, max score 11
# Completed 656 games, 1451 rewards, 345290 frames, score 0, max score 11
# Completed 657 games, 1452 rewards, 345544 frames, score 0, max score 11
# Completed 658 games, 1453 rewards, 345725 frames, score 0, max score 11
# Completed 659 games, 1454 rewards, 345933 frames, score 0, max score 11
# Completed 660 games, 1455 rewards, 346114 frames, score 0, max score 11
# Completed 661 games, 1462 rewards, 347436 frames, score 6, max score 11
# Completed 662 games, 1463 rewards, 347644 frames, score 0, max score 11
# Completed 663 games, 1464 rewards, 347825 frames, score 0, max score 11
# Completed 664 games, 1465 rewards, 348033 frames, score 0, max score 11
# Completed 665 games, 1467 rewards, 348545 frames, score 1, max score 11
# Completed 666 games, 1469 rewards, 348951 frames, score 1, max score 11
# Completed 667 games, 1470 rewards, 349205 frames, score 0, max score 11
# Completed 668 games, 1471 rewards, 349386 frames, score 0, max score 11
# Completed 669 games, 1476 rewards, 350368 frames, score 4, max score 11
# Completed 670 games, 1478 rewards, 350880 frames, score 1, max score 11
# Completed 671 games, 1485 rewards, 353969 frames, score 6, max score 11
# Completed 672 games, 1486 rewards, 354177 frames, score 0, max score 11
# Completed 673 games, 1492 rewards, 355486 frames, score 5, max score 11
# Completed 674 games, 1495 rewards, 356596 frames, score 2, max score 11
# Completed 675 games, 1497 rewards, 357002 frames, score 1, max score 11
# Completed 676 games, 1503 rewards, 358485 frames, score 5, max score 11
# Completed 677 games, 1506 rewards, 359134 frames, score 2, max score 11
# Completed 678 games, 1507 rewards, 359342 frames, score 0, max score 11
# Completed 679 games, 1508 rewards, 359596 frames, score 0, max score 11
# ...
# Completed 4794 games, 42543 rewards, 9481560 frames, score 12, max score 235
# Completed 4795 games, 42575 rewards, 9486363 frames, score 31, max score 235
# Completed 4796 games, 42589 rewards, 9490035 frames, score 13, max score 235
# Completed 4797 games, 42593 rewards, 9490847 frames, score 3, max score 235
# Completed 4798 games, 42597 rewards, 9491834 frames, score 3, max score 235
# Completed 4799 games, 42622 rewards, 9496023 frames, score 24, max score 235
# Completed 4800 games, 42626 rewards, 9496879 frames, score 3, max score 235
# Completed 4801 games, 42632 rewards, 9498257 frames, score 5, max score 235
# Completed 4802 games, 42639 rewards, 9499444 frames, score 6, max score 235
# Completed 4803 games, 42641 rewards, 9499907 frames, score 1, max score 235
# Completed 4804 games, 42646 rewards, 9500771 frames, score 4, max score 235
# Completed 4805 games, 42653 rewards, 9501905 frames, score 6, max score 235
# Completed 4806 games, 42658 rewards, 9502776 frames, score 4, max score 235
# Completed 4807 games, 42664 rewards, 9503849 frames, score 5, max score 235
# Completed 4808 games, 42670 rewards, 9505157 frames, score 5, max score 235
# Completed 4809 games, 42673 rewards, 9505958 frames, score 2, max score 235
# Completed 4810 games, 42680 rewards, 9509175 frames, score 6, max score 235
# Completed 4811 games, 42698 rewards, 9514345 frames, score 17, max score 235
# Completed 4812 games, 42722 rewards, 9519037 frames, score 23, max score 235
# Completed 4813 games, 42758 rewards, 9527427 frames, score 35, max score 235
# Completed 4814 games, 42773 rewards, 9529750 frames, score 14, max score 235
# Completed 4815 games, 42787 rewards, 9531971 frames, score 13, max score 235
# Completed 4816 games, 42837 rewards, 9543145 frames, score 49, max score 235
# Completed 4817 games, 42850 rewards, 9545366 frames, score 12, max score 235
# Completed 4818 games, 42854 rewards, 9546164 frames, score 3, max score 235
# Completed 4819 games, 42882 rewards, 9552111 frames, score 27, max score 235
# Completed 4820 games, 42896 rewards, 9554327 frames, score 13, max score 235
# Completed 4821 games, 42913 rewards, 9557558 frames, score 16, max score 235
# Completed 4822 games, 42950 rewards, 9567440 frames, score 36, max score 235
# Completed 4823 games, 42957 rewards, 9568729 frames, score 6, max score 235
# Completed 4824 games, 43061 rewards, 9590280 frames, score 103, max score 235
# Completed 4825 games, 43066 rewards, 9591663 frames, score 4, max score 235
# Completed 4826 games, 43078 rewards, 9598191 frames, score 11, max score 235
# Completed 4827 games, 43098 rewards, 9601314 frames, score 19, max score 235
# Completed 4828 games, 43107 rewards, 9603228 frames, score 8, max score 235
# Completed 4829 games, 43111 rewards, 9604066 frames, score 3, max score 235
# Completed 4830 games, 43148 rewards, 9620128 frames, score 36, max score 235
# Completed 4831 games, 43217 rewards, 9630827 frames, score 68, max score 235
# Completed 4832 games, 43254 rewards, 9645575 frames, score 36, max score 235
# Completed 4833 games, 43303 rewards, 9653947 frames, score 48, max score 235
# Completed 4834 games, 43317 rewards, 9656904 frames, score 13, max score 235
# Completed 4835 games, 43340 rewards, 9660492 frames, score 22, max score 235
# Completed 4836 games, 43345 rewards, 9661829 frames, score 4, max score 235
# Completed 4837 games, 43383 rewards, 9670835 frames, score 37, max score 235
# Completed 4838 games, 43386 rewards, 9671390 frames, score 2, max score 235
# Completed 4839 games, 43396 rewards, 9676048 frames, score 9, max score 235
# Completed 4840 games, 43404 rewards, 9677713 frames, score 7, max score 235
# Completed 4841 games, 43416 rewards, 9679490 frames, score 11, max score 235
# Completed 4842 games, 43432 rewards, 9684399 frames, score 15, max score 235
# Completed 4843 games, 43461 rewards, 9689779 frames, score 28, max score 235
# Completed 4844 games, 43465 rewards, 9690464 frames, score 3, max score 235
# Completed 4845 games, 43467 rewards, 9691015 frames, score 1, max score 235
# Completed 4846 games, 43485 rewards, 9694157 frames, score 17, max score 235
# Completed 4847 games, 43493 rewards, 9695815 frames, score 7, max score 235
# Completed 4848 games, 43501 rewards, 9698165 frames, score 7, max score 235
# Completed 4849 games, 43509 rewards, 9700345 frames, score 7, max score 235
# Completed 4850 games, 43514 rewards, 9701369 frames, score 4, max score 235
# Completed 4851 games, 43521 rewards, 9702929 frames, score 6, max score 235
# Completed 4852 games, 43531 rewards, 9704743 frames, score 9, max score 235
# Completed 4853 games, 43537 rewards, 9705795 frames, score 5, max score 235
# Completed 4854 games, 43546 rewards, 9707856 frames, score 8, max score 235
# Completed 4855 games, 43558 rewards, 9711608 frames, score 11, max score 235
# Completed 4856 games, 43560 rewards, 9712018 frames, score 1, max score 235
# Completed 4857 games, 43569 rewards, 9713584 frames, score 8, max score 235
# Completed 4858 games, 43570 rewards, 9713765 frames, score 0, max score 235
# Completed 4859 games, 43573 rewards, 9714394 frames, score 2, max score 235
# Completed 4860 games, 43574 rewards, 9714602 frames, score 0, max score 235
# Completed 4861 games, 43581 rewards, 9716206 frames, score 6, max score 235
# Completed 4862 games, 43590 rewards, 9717888 frames, score 8, max score 235
# Completed 4863 games, 43605 rewards, 9726291 frames, score 14, max score 235
# Completed 4864 games, 43611 rewards, 9728014 frames, score 5, max score 235
# Completed 4865 games, 43628 rewards, 9731835 frames, score 16, max score 235
# Completed 4866 games, 43635 rewards, 9733916 frames, score 6, max score 235
# Completed 4867 games, 43659 rewards, 9739138 frames, score 23, max score 235
# Completed 4868 games, 43665 rewards, 9740275 frames, score 5, max score 235
# Completed 4869 games, 43686 rewards, 9745977 frames, score 20, max score 235
# Completed 4870 games, 43720 rewards, 9751670 frames, score 33, max score 235
# Completed 4871 games, 43739 rewards, 9755021 frames, score 18, max score 235
# Completed 4872 games, 43749 rewards, 9760714 frames, score 9, max score 235
# Completed 4873 games, 43753 rewards, 9761379 frames, score 3, max score 235
# Completed 4874 games, 43765 rewards, 9764185 frames, score 11, max score 235
# Completed 4875 games, 43781 rewards, 9766983 frames, score 15, max score 235
# Completed 4876 games, 43786 rewards, 9767994 frames, score 4, max score 235
# Completed 4877 games, 43808 rewards, 9771660 frames, score 21, max score 235
# Completed 4878 games, 43841 rewards, 9780484 frames, score 32, max score 235
# Completed 4879 games, 43856 rewards, 9783023 frames, score 14, max score 235
# Completed 4880 games, 43890 rewards, 9788244 frames, score 33, max score 235
# Completed 4881 games, 43928 rewards, 9795308 frames, score 37, max score 235
# Completed 4882 games, 43934 rewards, 9796332 frames, score 5, max score 235
# Completed 4883 games, 43935 rewards, 9796513 frames, score 0, max score 235
# Completed 4884 games, 43940 rewards, 9797541 frames, score 4, max score 235
# Completed 4885 games, 43953 rewards, 9803692 frames, score 12, max score 235
# Completed 4886 games, 43981 rewards, 9808112 frames, score 27, max score 235
# Completed 4887 games, 43984 rewards, 9808666 frames, score 2, max score 235
# Completed 4888 games, 44007 rewards, 9812130 frames, score 22, max score 235
# Completed 4889 games, 44038 rewards, 9816805 frames, score 30, max score 235
# Completed 4890 games, 44048 rewards, 9819836 frames, score 9, max score 235
# Completed 4891 games, 44076 rewards, 9825066 frames, score 27, max score 235
# Completed 4892 games, 44092 rewards, 9828217 frames, score 15, max score 235
# Completed 4893 games, 44119 rewards, 9833197 frames, score 26, max score 235
# Completed 4894 games, 44142 rewards, 9836596 frames, score 22, max score 235
# Completed 4895 games, 44148 rewards, 9837868 frames, score 5, max score 235
# Completed 4896 games, 44153 rewards, 9838903 frames, score 4, max score 235
# Completed 4897 games, 44156 rewards, 9840068 frames, score 2, max score 235
# Completed 4898 games, 44188 rewards, 9845103 frames, score 31, max score 235
# Completed 4899 games, 44192 rewards, 9845892 frames, score 3, max score 235
# Completed 4900 games, 44235 rewards, 9858965 frames, score 42, max score 235
# Completed 4901 games, 44251 rewards, 9868919 frames, score 15, max score 235
# Completed 4902 games, 44258 rewards, 9870317 frames, score 6, max score 235
# Completed 4903 games, 44267 rewards, 9872280 frames, score 8, max score 235
# Completed 4904 games, 44307 rewards, 9882575 frames, score 39, max score 235
# Completed 4905 games, 44324 rewards, 9885389 frames, score 16, max score 235
# Completed 4906 games, 44334 rewards, 9887125 frames, score 9, max score 235
# Completed 4907 games, 44336 rewards, 9887588 frames, score 1, max score 235
# Completed 4908 games, 44352 rewards, 9891715 frames, score 15, max score 235
# Completed 4909 games, 44371 rewards, 9894809 frames, score 18, max score 235
# Completed 4910 games, 44385 rewards, 9896888 frames, score 13, max score 235
# Completed 4911 games, 44420 rewards, 9911724 frames, score 34, max score 235
# Completed 4912 games, 44426 rewards, 9912927 frames, score 5, max score 235
# Completed 4913 games, 44438 rewards, 9916068 frames, score 11, max score 235
# Completed 4914 games, 44442 rewards, 9916772 frames, score 3, max score 235
# Completed 4915 games, 44445 rewards, 9917498 frames, score 2, max score 235
# Completed 4916 games, 44448 rewards, 9918149 frames, score 2, max score 235
# Completed 4917 games, 44451 rewards, 9918737 frames, score 2, max score 235
# Completed 4918 games, 44475 rewards, 9924684 frames, score 23, max score 235
# Completed 4919 games, 44488 rewards, 9927171 frames, score 12, max score 235
# Completed 4920 games, 44514 rewards, 9937790 frames, score 25, max score 235
# Completed 4921 games, 44519 rewards, 9939093 frames, score 4, max score 235
# Completed 4922 games, 44533 rewards, 9941577 frames, score 13, max score 235
# Completed 4923 games, 44538 rewards, 9942558 frames, score 4, max score 235
# Completed 4924 games, 44544 rewards, 9943700 frames, score 5, max score 235
# Completed 4925 games, 44599 rewards, 9963667 frames, score 54, max score 235
# Completed 4926 games, 44607 rewards, 9965261 frames, score 7, max score 235
# Completed 4927 games, 44623 rewards, 9971484 frames, score 15, max score 235
# Completed 4928 games, 44625 rewards, 9972035 frames, score 1, max score 235
# Completed 4929 games, 44628 rewards, 9972852 frames, score 2, max score 235
# Completed 4930 games, 44641 rewards, 9975312 frames, score 12, max score 235
# Completed 4931 games, 44642 rewards, 9975566 frames, score 0, max score 235
# Completed 4932 games, 44697 rewards, 9988405 frames, score 54, max score 235
# Completed 4933 games, 44699 rewards, 9989007 frames, score 1, max score 235
# Completed 4934 games, 44707 rewards, 9992000 frames, score 7, max score 235
# Completed 4935 games, 44733 rewards, 9996490 frames, score 25, max score 235
# Completed 4936 games, 44749 rewards, 10002300 frames, score 15, max score 235
# Completed 4937 games, 44774 rewards, 10006977 frames, score 24, max score 235
# Completed 4938 games, 44779 rewards, 10008166 frames, score 4, max score 235
# Completed 4939 games, 44780 rewards, 10008374 frames, score 0, max score 235
# Completed 4940 games, 44784 rewards, 10009806 frames, score 3, max score 235
# Completed 4941 games, 44812 rewards, 10015844 frames, score 27, max score 235
# Completed 4942 games, 44822 rewards, 10017425 frames, score 9, max score 235
# Completed 4943 games, 44825 rewards, 10018013 frames, score 2, max score 235
# Completed 4944 games, 44836 rewards, 10022004 frames, score 10, max score 235
# Completed 4945 games, 44850 rewards, 10024298 frames, score 13, max score 235
# Completed 4946 games, 44852 rewards, 10024758 frames, score 1, max score 235
# Completed 4947 games, 44865 rewards, 10030985 frames, score 12, max score 235
# Completed 4948 games, 44872 rewards, 10032853 frames, score 6, max score 235
# Completed 4949 games, 44874 rewards, 10033443 frames, score 1, max score 235
# Completed 4950 games, 44924 rewards, 10045177 frames, score 49, max score 235
# Completed 4951 games, 44938 rewards, 10049963 frames, score 13, max score 235
# Completed 4952 games, 44954 rewards, 10052324 frames, score 15, max score 235
# Completed 4953 games, 44960 rewards, 10053484 frames, score 5, max score 235
# Completed 4954 games, 44970 rewards, 10055504 frames, score 9, max score 235
# Completed 4955 games, 45033 rewards, 10064888 frames, score 62, max score 235
# Completed 4956 games, 45040 rewards, 10066015 frames, score 6, max score 235
# Completed 4957 games, 45049 rewards, 10067550 frames, score 8, max score 235
# Completed 4958 games, 45058 rewards, 10069076 frames, score 8, max score 235
# Completed 4959 games, 45072 rewards, 10073994 frames, score 13, max score 235
# Completed 4960 games, 45084 rewards, 10076168 frames, score 11, max score 235
# Completed 4961 games, 45089 rewards, 10076939 frames, score 4, max score 235
# Completed 4962 games, 45103 rewards, 10081054 frames, score 13, max score 235
# Completed 4963 games, 45136 rewards, 10087195 frames, score 32, max score 235
# Completed 4964 games, 45173 rewards, 10093409 frames, score 36, max score 235
# Completed 4965 games, 45206 rewards, 10099089 frames, score 32, max score 235
# Completed 4966 games, 45212 rewards, 10100109 frames, score 5, max score 235
# Completed 4967 games, 45227 rewards, 10104076 frames, score 14, max score 235
# Completed 4968 games, 45263 rewards, 10109727 frames, score 35, max score 235
# Completed 4969 games, 45299 rewards, 10115712 frames, score 35, max score 235
# Completed 4970 games, 45320 rewards, 10119015 frames, score 20, max score 235
# Completed 4971 games, 45332 rewards, 10121135 frames, score 11, max score 235
# Completed 4972 games, 45406 rewards, 10132453 frames, score 73, max score 235
# Completed 4973 games, 45424 rewards, 10137218 frames, score 17, max score 235
# Completed 4974 games, 45457 rewards, 10143325 frames, score 32, max score 235
# Completed 4975 games, 45477 rewards, 10149502 frames, score 19, max score 235
# Completed 4976 games, 45511 rewards, 10155203 frames, score 33, max score 235
# Completed 4977 games, 45521 rewards, 10157199 frames, score 9, max score 235
# Completed 4978 games, 45527 rewards, 10158842 frames, score 5, max score 235
# Completed 4979 games, 45528 rewards, 10159023 frames, score 0, max score 235
# Completed 4980 games, 45534 rewards, 10160545 frames, score 5, max score 235
# Completed 4981 games, 45550 rewards, 10162967 frames, score 15, max score 235
# Completed 4982 games, 45555 rewards, 10163827 frames, score 4, max score 235
# Completed 4983 games, 45592 rewards, 10170039 frames, score 36, max score 235
# Completed 4984 games, 45650 rewards, 10180049 frames, score 57, max score 235
# Completed 4985 games, 45719 rewards, 10191481 frames, score 68, max score 235
# Completed 4986 games, 45739 rewards, 10196042 frames, score 19, max score 235
# Completed 4987 games, 45751 rewards, 10199890 frames, score 11, max score 235
# Completed 4988 games, 45761 rewards, 10201481 frames, score 9, max score 235
# Completed 4989 games, 45777 rewards, 10203881 frames, score 15, max score 235
# Completed 4990 games, 45797 rewards, 10207056 frames, score 19, max score 235
# Completed 4991 games, 45810 rewards, 10210256 frames, score 12, max score 235
# Completed 4992 games, 45813 rewards, 10210871 frames, score 2, max score 235
# Completed 4993 games, 45854 rewards, 10217209 frames, score 40, max score 235
# Completed 4994 games, 45932 rewards, 10232058 frames, score 77, max score 235
# Completed 4995 games, 46019 rewards, 10252373 frames, score 86, max score 235
# Completed 4996 games, 46039 rewards, 10255796 frames, score 19, max score 235
# Completed 4997 games, 46167 rewards, 10276093 frames, score 127, max score 235
# Completed 4998 games, 46362 rewards, 10306505 frames, score 194, max score 235
# Completed 4999 games, 46398 rewards, 10312029 frames, score 35, max score 235
# The number of games played was 5000
# The number of video frames was 5000
# The size of each returned Q-matrix was (0,)

# %% [markdown]
# Now let's plot the score, to see if it improved over time.  We will also plot the local average, averaged over 10 consecutive games, to see if that has improved.  Notice that we can use `np.convolve` to compute the local average.
#
# These numbers are really noisy, with a really large maximum.  We will plot `np.log10(1+x)`, rather than x, so that we can better see the average numbers, and ignore the very large noisy spikes.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

fig = plt.figure(figsize=(14,9),layout='tight')
ax = [ fig.add_subplot(3,1,x) for x in range(1,4) ]
ax[0].plot(np.arange(0,len(scores)),np.log10(1+np.array(scores)))
ax[0].plot([0,5000],np.log10([7,7]),'k--')
ax[0].set_title('Game scores')
ax[1].plot(np.arange(4991),np.log10(1+np.convolve(np.ones(10)/10,scores,mode='valid')))
ax[1].plot([0,4991],np.log10([7,7]),'k--')
ax[1].set_title('Game scores, average 10 consecutive games')
ax[2].plot(np.arange(0,len(q_achieved)),q_achieved)
ax[2].set_title('Q values of state achieved at each time')
ax[2].set_ylabel('Game number')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/2r/cp80ny451xv3lxv7_ktzrlsw0000gp/T/ipykernel_739/698078239.py in <module>
#       3 import matplotlib.pyplot as plt
#       4
# ----> 5 fig = plt.figure(figsize=(14,9),layout='tight')
#       6 ax = [ fig.add_subplot(3,1,x) for x in range(1,4) ]
#       7 ax[0].plot(np.arange(0,len(scores)),np.log10(1+np.array(scores)))
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     795                 RuntimeWarning)
#     796
# --> 797         manager = new_figure_manager(
#     798             num, figsize=figsize, dpi=dpi,
#     799             facecolor=facecolor, edgecolor=edgecolor, frameon=frameon,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/pyplot.py in new_figure_manager(*args, **kwargs)
#     314     """Create a new figure manager instance."""
#     315     _warn_if_gui_out_of_main_thread()
# --> 316     return _backend_mod.new_figure_manager(*args, **kwargs)
#     317
#     318
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backend_bases.py in new_figure_manager(cls, num, *args, **kwargs)
#    3542         from matplotlib.figure import Figure
#    3543         fig_cls = kwargs.pop('FigureClass', Figure)
# -> 3544         fig = fig_cls(*args, **kwargs)
#    3545         return cls.new_figure_manager_given_figure(num, fig)
#    3546
#
# TypeError: __init__() got an unexpected keyword argument 'layout'

# %% [markdown]
# Hooray, it has learned!  If you are getting a ten-game average score of better than 6, then you are ready to submit your model for grading.   In order to do that, you need to save the model:

# %%
q_learner.save('trained_model.npz')

# %% [markdown]
# <a id='section9'></a>

# %% [markdown]
# ## Extra Credit

# %% [markdown]
# For extra credit, download the file <a href="mp11_extra.zip">mp11_extra.zip</a>.  The only important file in this package is:
# * `tests/test_extra.py`: this contains extra tests that will evaluate your pre-trained `deep_q` learner, which should be in a file called `trained_model.pkl`.  For full credit, your model should achieve an average score of greater than 20, averaged over 10 consecutive games.
#
# With a quantized lookup table, it's probably not possible to achieve an average score of 20.  With a deep-Q learner, however, it is eminently possible.  In order to do the extra credit, therefore, you should just fill in the part of `submitted.py` that implements the `deep_q` learner, using pytorch to define a model structure, train it, save it, load it, and act on it.  This learner only needs to have five methods: `__init__`, `act`, `learn`, `save`, and `load`:

# %%
importlib.reload(submitted)
help(submitted.deep_q.__init__)
# Out:
# Help on function __init__ in module submitted:
#
# __init__(self, alpha, epsilon, gamma, nfirst)
#     Create a new deep_q learner.
#     Your q_learner object should store the provided values of alpha,
#     epsilon, gamma, and nfirst.
#     It should also create a deep learning model that will accept
#     (state,action) as input, and estimate Q as the output.
#
#     @params:
#     alpha (scalar) - learning rate of the Q-learner
#     epsilon (scalar) - probability of taking a random action
#     gamma (scalar) - discount factor
#     nfirst (scalar) - exploring each state/action pair nfirst times before exploiting
#
#     @return:
#     None

# %%
help(submitted.deep_q.act)
# Out:
# Help on function act in module submitted:
#
# act(self, state)
#     Decide what action to take in the current state.
#     You are free to determine your own exploration/exploitation policy --
#     you don't need to use the epsilon and nfirst provided to you.
#
#     @params:
#     state: a list of 5 floats: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#
#     @return:
#     -1 if the paddle should move upward
#     0 if the paddle should be stationary
#     1 if the paddle should move downward

# %%
help(submitted.deep_q.learn)
# Out:
# Help on function learn in module submitted:
#
# learn(self, state, action, reward, newstate)
#     Perform one iteration of training on a deep-Q model.
#
#     @params:
#     state: a list of 5 floats: ball_x, ball_y, ball_vx, ball_vy, paddle_y
#     action: an integer, one of -1, 0, or +1
#     reward: a reward; positive for hitting the ball, negative for losing a game
#     newstate: a list of 5 floats, in the same format as state
#
#     @return:
#     None

# %%
help(submitted.deep_q.save)
# Out:
# Help on function save in module submitted:
#
# save(self, filename)
#     Save your trained deep-Q model to a file.
#     This can save in any format you like, as long as your "load"
#     function uses the same file format.
#
#     @params:
#     filename (str) - filename to which it should be saved
#     @return:
#     None

# %%
help(submitted.deep_q.load)
# Out:
# Help on function load in module submitted:
#
# load(self, filename)
#     Load your deep-Q model from a file.
#     This should load from whatever file format your save function
#     used.
#
#     @params:
#     filename (str) - filename from which it should be loaded
#     @return:
#     None

# %% [markdown]
# <a id='grade'></a>

# %% [markdown]
# ## Grade your homework

# %% [markdown]
# If you've reached this point, and all of the above sections work, then you're ready to try grading your homework!  Before you submit it to Gradescope, try grading it on your own machine.  This will run some visible test cases (which you can read in `tests/test_visible.py`), and compare the results to the solutions (which you can read in `solution.json`).
#
# The exclamation point (!) tells python to run the following as a shell command.  Obviously you don't need to run the code this way -- this usage is here just to remind you that you can also, if you wish, run this command in a terminal window.

# %%
# !python grade.py
# Out:
# E
# ======================================================================
# ERROR: test_visible (unittest.loader.ModuleImportFailure)
# ----------------------------------------------------------------------
# ImportError: Failed to import test module: test_visible
# Traceback (most recent call last):
#   File "/System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/unittest/loader.py", line 254, in _find_tests
#     module = self._get_module_from_name(name)
#   File "/System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/unittest/loader.py", line 232, in _get_module_from_name
#     __import__(name)
#   File "/Users/natzhou/Desktop/CS 440/mp11/tests/test_visible.py", line 1, in <module>
#     import unittest, json, submitted
#   File "/Users/natzhou/Desktop/CS 440/mp11/submitted.py", line 10, in <module>
#     import torch
# ImportError: No module named torch
#
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.000s
#
# FAILED (errors=1)

# %% [markdown]
# Now you should try uploading your code to <a href="https://www.gradescope.com/courses/486387">Gradescope</a>.
#
# **Warning:** For this MP you need to update two files, not just one.
# * `trained_model.npz` should contain your trained model
# * `submitted.py` should contain your code that loads and runs your trained model.
#
# **Warning:** The autograder calculates the average score over ten random games.  If you are getting an average score above 10 almost all the time on your own computer, and if the autograder says you had a score below 10, try resubmitting to see if the next round of random games is better.
#
# **Extra Credit:** Your extra credit should also be uploaded as two files,
# * `trained_model.pkl` should contain your trained model
# * `submitted.py` should contain your code that loads and runs your trained model.
